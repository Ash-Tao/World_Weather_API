# %% [markdown]
# # WeatherPy
# ----
#
# ### Description:
# Trends 1: In the Northern Hemisphere, temperature decreases with increasing latitude.<br/>
# Trends 2: In the Southern Hemisphere, temperature increases with latitude.<br/>
#
# The equator has the highest temperature, and the temperature gradually decreases as it moves along the equator towards the earth's poles.<br/>
# But overall temperatures in the southern hemisphere are higher than in the northern hemisphere.This is because the surface in the Southern Hemisphere has more water. And water has a high specific heat capacity so it loses heat slowly.<br/>
# I also discovered this while doing the Generate Cities List. For haveing the similar amount of data(300 cities), I only need 600 random points in the southern hemisphere,but 1600 in the northern hemisphere.<br/>
# The difference in land area between the northern and southern hemispheres also affects the Linear Regression plot. <br/>There is a very strong negative correlation between Max Temp Latitude in the Northern Hemisphere. However, the correlation in Southern Hemisphere becomes weaker due to this difference, which showes a moderate correlation.<br/>
# <br/>
# Trends 3: There are clear clumps at 0% and 100%, and less clear clumps at 75%, 40% and 20%.<br/>
# But there is no significant correlation between latitude and Cloudiness.<br/>

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_WeatherPy/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
north_lat_lngs = []
north_cities = []
south_cities =[]

# Create a set of random lat and lng combinations
north_lats = np.random.uniform(low=0, high=90.000, size=600)
north_lngs = np.random.uniform(low=-180.000, high=180.000, size=600)
north_lat_lngs = zip(north_lats, north_lngs)

# Identify nearest city for each lat, lng combination
for north_lat_lng in north_lat_lngs:
    north_city = citipy.nearest_city(north_lat_lng[0], north_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if north_city not in north_cities:
        north_cities.append(north_city)

# Create a set of random lat and lng combinations
south_lats = np.random.uniform(low=-90.000, high=0, size=1600)
south_lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
south_lat_lngs = zip(south_lats, south_lngs)

# Identify nearest city for each lat, lng combination
for south_lat_lng in south_lat_lngs:
    south_city = citipy.nearest_city(south_lat_lng[0], south_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if south_city not in south_cities:
        south_cities.append(south_city)
        
# Print the city count to confirm sufficient count
print(f'Exported {len(north_cities)} cities in the Northern Hemisphere')
print(f'Exported {len(south_cities)} cities in the Southern Hemisphere')
# Out:
# Exported 344 cities in the Northern Hemisphere
# Exported 328 cities in the Southern Hemisphere

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
clouds = []
country = []
date = []
tempmax = []
humidity = []
lat = []
lon = []
windspeed = []
cityname = []

# use loop to get all the column value.
# use try to exclusive the city that can't be found.

#doesn't mention the task relate to temperate history. Therefore, use the current API.
k=1
for city in north_cities:
    if len(cityname)<270:
        units="imperial"
        url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
        weater_detail = requests.get(url_weater).json()
        try: 
            clouds.append(weater_detail["clouds"]["all"])
            country.append(weater_detail["sys"]["country"])
            date.append(weater_detail["dt"])
            tempmax.append(weater_detail["main"]['temp_max'])
            humidity.append(weater_detail["main"]['humidity'])
            lat.append(weater_detail["coord"]["lat"])  
            lon.append(weater_detail["coord"]["lon"])
            windspeed.append(weater_detail["wind"]["speed"])
            cityname.append(weater_detail["name"])
            print(f"Processing record {k}|{city}")
            k+=1
        except (KeyError):
            print("City is not found. skipping.")

for city in south_cities:
    if len(cityname)<540:
        units="imperial"
        url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
        weater_detail = requests.get(url_weater).json()
        try: 
            clouds.append(weater_detail["clouds"]["all"])
            country.append(weater_detail["sys"]["country"])
            date.append(weater_detail["dt"])
            tempmax.append(weater_detail["main"]['temp_max'])
            humidity.append(weater_detail["main"]['humidity'])
            lat.append(weater_detail["coord"]["lat"])  
            lon.append(weater_detail["coord"]["lon"])
            windspeed.append(weater_detail["wind"]["speed"])
            cityname.append(weater_detail["name"])
            print(f"Processing record {k}|{city}")
            k+=1
        except (KeyError):
            print("City is not found. skipping.")
# Out:
# Processing record 1|khatanga
# Processing record 2|deer lake
# City is not found. skipping.
# Processing record 3|kavieng
# Processing record 4|barrow
# Processing record 5|butaritari
# Processing record 6|kapaa
# Processing record 7|klyuchi
# Processing record 8|leningradskiy
# Processing record 9|safaga
# Processing record 10|regidor
# Processing record 11|igrim
# City is not found. skipping.
# Processing record 12|zigong
# Processing record 13|bakaly
# Processing record 14|joshimath
# Processing record 15|aloleng
# Processing record 16|severo-kurilsk
# Processing record 17|jasper
# Processing record 18|lompoc
# City is not found. skipping.
# Processing record 19|qaanaaq
# Processing record 20|atuona
# City is not found. skipping.
# Processing record 21|hilo
# Processing record 22|esso
# Processing record 23|bartica
# Processing record 24|korla
# Processing record 25|nikolskoye
# Processing record 26|evensk
# Processing record 27|nevelsk
# Processing record 28|berbera
# Processing record 29|los llanos de aridane
# Processing record 30|ostrovnoy
# Processing record 31|upernavik
# Processing record 32|kropotkin
# Processing record 33|hay river
# Processing record 34|mirabad
# Processing record 35|bathsheba
# Processing record 36|cabo san lucas
# City is not found. skipping.
# Processing record 37|zhezkazgan
# Processing record 38|pahrump
# Processing record 39|umm kaddadah
# Processing record 40|norman wells
# Processing record 41|saint-francois
# Processing record 42|dikson
# Processing record 43|allapalli
# Processing record 44|qingdao
# Processing record 45|pevek
# Processing record 46|felanitx
# Processing record 47|ponta do sol
# Processing record 48|cherskiy
# Processing record 49|sitka
# Processing record 50|torbay
# Processing record 51|sebring
# Processing record 52|codrington
# Processing record 53|nakusp
# Processing record 54|ribeira grande
# Processing record 55|husavik
# Processing record 56|bani
# Processing record 57|jurado
# Processing record 58|kahului
# Processing record 59|newport
# Processing record 60|mangan
# Processing record 61|liverpool
# Processing record 62|saskylakh
# Processing record 63|hami
# City is not found. skipping.
# Processing record 64|chokurdakh
# Processing record 65|bandarbeyla
# Processing record 66|atar
# Processing record 67|mayo
# City is not found. skipping.
# Processing record 68|ugoofaaru
# Processing record 69|yunhe
# Processing record 70|san patricio
# Processing record 71|longyearbyen
# Processing record 72|tasiilaq
# Processing record 73|wanning
# Processing record 74|zhangjiakou
# Processing record 75|sembe
# Processing record 76|bereda
# Processing record 77|itarema
# Processing record 78|kamnik
# Processing record 79|marrakesh
# City is not found. skipping.
# Processing record 80|fort-shevchenko
# Processing record 81|egvekinot
# Processing record 82|nemuro
# City is not found. skipping.
# City is not found. skipping.
# Processing record 83|garmsar
# Processing record 84|yumen
# Processing record 85|kumbo
# Processing record 86|airai
# Processing record 87|sayyan
# Processing record 88|yellowknife
# Processing record 89|leh
# City is not found. skipping.
# Processing record 90|dalbandin
# Processing record 91|erdemli
# Processing record 92|lagoa
# Processing record 93|kungurtug
# Processing record 94|zanesville
# Processing record 95|guerrero negro
# Processing record 96|meulaboh
# City is not found. skipping.
# Processing record 97|pacific grove
# Processing record 98|altar
# Processing record 99|sidi ali
# Processing record 100|haimen
# Processing record 101|pella
# Processing record 102|vaxjo
# Processing record 103|vung tau
# Processing record 104|manhattan
# Processing record 105|nanortalik
# Processing record 106|karpathos
# Processing record 107|cockburn town
# City is not found. skipping.
# Processing record 108|angul
# Processing record 109|xining
# Processing record 110|kupino
# Processing record 111|ternate
# Processing record 112|pinega
# Processing record 113|puerto ayora
# Processing record 114|iwanai
# Processing record 115|keningau
# Processing record 116|samoded
# Processing record 117|baie-comeau
# Processing record 118|isabela
# Processing record 119|ishigaki
# Processing record 120|glenwood springs
# Processing record 121|vila franca do campo
# City is not found. skipping.
# Processing record 122|tuktoyaktuk
# Processing record 123|sao filipe
# Processing record 124|nantucket
# Processing record 125|sisimiut
# City is not found. skipping.
# Processing record 126|odweyne
# Processing record 127|taunggyi
# Processing record 128|nanakuli
# Processing record 129|talnakh
# Processing record 130|saint george
# Processing record 131|vuktyl
# Processing record 132|tromso
# Processing record 133|mayya
# Processing record 134|thompson
# Processing record 135|cosamaloapan
# Processing record 136|la ronge
# Processing record 137|aransas pass
# City is not found. skipping.
# Processing record 138|berlevag
# Processing record 139|provideniya
# Processing record 140|taman
# Processing record 141|makakilo city
# Processing record 142|kamenka
# Processing record 143|clyde river
# Processing record 144|klaksvik
# Processing record 145|hasaki
# Processing record 146|petrivka
# Processing record 147|lhokseumawe
# Processing record 148|shingu
# Processing record 149|sankheda
# Processing record 150|iqaluit
# Processing record 151|bow island
# Processing record 152|baiyin
# Processing record 153|asyut
# Processing record 154|heishan
# Processing record 155|half moon bay
# Processing record 156|nuuk
# Processing record 157|santa cruz
# Processing record 158|warrington
# Processing record 159|bosaso
# Processing record 160|ozinki
# City is not found. skipping.
# Processing record 161|dingle
# Processing record 162|mecca
# Processing record 163|burgdorf
# Processing record 164|vestmannaeyjar
# Processing record 165|hofn
# Processing record 166|portales
# Processing record 167|turukhansk
# Processing record 168|zhigansk
# City is not found. skipping.
# Processing record 169|pierre
# Processing record 170|eureka
# Processing record 171|tulum
# Processing record 172|cayenne
# Processing record 173|vostok
# Processing record 174|san juan de uraba
# Processing record 175|touros
# Processing record 176|krasnoselkup
# Processing record 177|vardo
# Processing record 178|raga
# Processing record 179|gasa
# Processing record 180|sindi
# Processing record 181|iralaya
# Processing record 182|abha
# Processing record 183|lerwick
# Processing record 184|ostroleka
# Processing record 185|saint-pierre
# Processing record 186|edea
# Processing record 187|bria
# Processing record 188|tiksi
# Processing record 189|sterling
# Processing record 190|adjumani
# Processing record 191|lexington
# City is not found. skipping.
# Processing record 192|anadyr
# Processing record 193|beeville
# Processing record 194|silveira
# Processing record 195|oussouye
# Processing record 196|umred
# Processing record 197|kodiak
# Processing record 198|luhyny
# Processing record 199|buchanan
# Processing record 200|creel
# City is not found. skipping.
# Processing record 201|forecariah
# Processing record 202|phayao
# Processing record 203|lavrentiya
# Processing record 204|naujoji akmene
# Processing record 205|tilichiki
# Processing record 206|albert
# Processing record 207|hobyo
# Processing record 208|morristown
# Processing record 209|basco
# Processing record 210|udachnyy
# Processing record 211|fort nelson
# Processing record 212|dawlatabad
# Processing record 213|yaan
# Processing record 214|bethel
# Processing record 215|chelmno
# Processing record 216|ous
# Processing record 217|davila
# Processing record 218|sioux lookout
# Processing record 219|fairbanks
# Processing record 220|villaviciosa
# Processing record 221|severnyy-kospashskiy
# Processing record 222|silver city
# Processing record 223|taitung
# Processing record 224|ilulissat
# Processing record 225|naze
# Processing record 226|rosarito
# Processing record 227|bintulu
# City is not found. skipping.
# Processing record 228|paks
# Processing record 229|hailar
# Processing record 230|obuasi
# Processing record 231|naples
# Processing record 232|akyab
# Processing record 233|pangnirtung
# Processing record 234|robertsport
# Processing record 235|acarau
# Processing record 236|key west
# Processing record 237|zheleznodorozhnyy
# Processing record 238|alberton
# City is not found. skipping.
# Processing record 239|alamosa
# Processing record 240|dali
# Processing record 241|victoria
# Processing record 242|abu samrah
# Processing record 243|ventspils
# Processing record 244|saint-augustin
# Processing record 245|novyy urengoy
# Processing record 246|jedburgh
# Processing record 247|barahona
# Processing record 248|verkhoyansk
# Processing record 249|moron
# Processing record 250|oxford
# City is not found. skipping.
# City is not found. skipping.
# Processing record 251|north bend
# Processing record 252|nacogdoches
# City is not found. skipping.
# Processing record 253|aborlan
# Processing record 254|springdale
# Processing record 255|muskegon
# Processing record 256|pala
# Processing record 257|arlit
# Processing record 258|derzhavinsk
# Processing record 259|nikel
# Processing record 260|taseyevo
# Processing record 261|fallon
# Processing record 262|leo
# Processing record 263|slavonski brod
# Processing record 264|west fargo
# Processing record 265|leshukonskoye
# Processing record 266|yanji
# Processing record 267|rosetta
# Processing record 268|gat
# Processing record 269|inuvik
# Processing record 270|ola
# Processing record 271|praya
# City is not found. skipping.
# Processing record 272|puerto ayora
# Processing record 273|atuona
# Processing record 274|mogadishu
# Processing record 275|bredasdorp
# Processing record 276|carnarvon
# Processing record 277|east london
# Processing record 278|jamestown
# Processing record 279|mataura
# Processing record 280|arraial do cabo
# Processing record 281|ushuaia
# Processing record 282|rikitea
# Processing record 283|mount gambier
# Processing record 284|busselton
# Processing record 285|saldanha
# Processing record 286|joao neiva
# Processing record 287|axim
# Processing record 288|neiafu
# Processing record 289|pisco
# Processing record 290|george
# Processing record 291|sawtell
# Processing record 292|cape town
# Processing record 293|roma
# Processing record 294|esperance
# Processing record 295|port lincoln
# City is not found. skipping.
# Processing record 296|isangel
# Processing record 297|punta arenas
# Processing record 298|port elizabeth
# Processing record 299|san ramon de la nueva oran
# City is not found. skipping.
# Processing record 300|bluff
# Processing record 301|te anau
# Processing record 302|codajas
# Processing record 303|albany
# Processing record 304|castro
# Processing record 305|avarua
# Processing record 306|hermanus
# Processing record 307|hithadhoo
# Processing record 308|faanui
# Processing record 309|phalaborwa
# Processing record 310|metro
# Processing record 311|saint-philippe
# Processing record 312|ihosy
# Processing record 313|hobart
# Processing record 314|lebu
# Processing record 315|victoria
# Processing record 316|bellavista
# Processing record 317|port alfred
# City is not found. skipping.
# Processing record 318|alofi
# Processing record 319|mount isa
# Processing record 320|san pedro de ycuamandiyu
# Processing record 321|lata
# Processing record 322|coromandel
# City is not found. skipping.
# City is not found. skipping.
# Processing record 323|kruisfontein
# Processing record 324|touros
# Processing record 325|geraldton
# Processing record 326|bambous virieux
# Processing record 327|georgetown
# Processing record 328|souillac
# Processing record 329|san cristobal
# Processing record 330|vaini
# Processing record 331|kaniama
# Processing record 332|mar del plata
# Processing record 333|vao
# Processing record 334|galesong
# Processing record 335|laguna
# Processing record 336|grand gaube
# Processing record 337|barroquinha
# Processing record 338|necochea
# Processing record 339|port augusta
# Processing record 340|mandurah
# Processing record 341|meulaboh
# Processing record 342|poum
# Processing record 343|cidreira
# Processing record 344|coquimbo
# Processing record 345|port-gentil
# Processing record 346|saquena
# Processing record 347|tocopilla
# Processing record 348|paita
# Processing record 349|sola
# Processing record 350|luderitz
# Processing record 351|quatre cocos
# Processing record 352|santo angelo
# Processing record 353|new norfolk
# Processing record 354|san patricio
# Processing record 355|yulara
# Processing record 356|mansa
# Processing record 357|belmonte
# Processing record 358|dunedin
# Processing record 359|viedma
# City is not found. skipping.
# Processing record 360|deniliquin
# Processing record 361|fenoarivo atsinanana
# Processing record 362|pangai
# Processing record 363|ambon
# Processing record 364|rawson
# Processing record 365|tual
# Processing record 366|vallenar
# Processing record 367|vila velha
# Processing record 368|flinders
# Processing record 369|nortelandia
# Processing record 370|sao jose da coroa grande
# Processing record 371|kaitangata
# City is not found. skipping.
# Processing record 372|sao joao da barra
# Processing record 373|bengkulu
# Processing record 374|ntcheu
# City is not found. skipping.
# Processing record 375|illapel
# Processing record 376|westport
# Processing record 377|musoma
# Processing record 378|merauke
# Processing record 379|kirakira
# Processing record 380|santiago del estero
# Processing record 381|amahai
# Processing record 382|ancud
# Processing record 383|presidencia roque saenz pena
# Processing record 384|grootfontein
# Processing record 385|sao felix do xingu
# Processing record 386|tiarei
# Processing record 387|alice springs
# Processing record 388|buala
# Processing record 389|maragogi
# Processing record 390|tabou
# Processing record 391|kimbe
# Processing record 392|carutapera
# Processing record 393|kasongo-lunda
# Processing record 394|tamandare
# Processing record 395|sambava
# City is not found. skipping.
# Processing record 396|monteagudo
# Processing record 397|linhares
# Processing record 398|leua
# Processing record 399|mahebourg
# Processing record 400|portland
# Processing record 401|knysna
# Processing record 402|coihaique
# Processing record 403|chuy
# Processing record 404|caravelas
# Processing record 405|orapa
# Processing record 406|joao monlevade
# Processing record 407|tuatapere
# Processing record 408|fare
# Processing record 409|katobu
# Processing record 410|karratha
# Processing record 411|corbelia
# Processing record 412|sacramento
# Processing record 413|walvis bay
# Processing record 414|gamba
# Processing record 415|sorong
# City is not found. skipping.
# Processing record 416|tacuarembo
# Processing record 417|aracati
# Processing record 418|valenca do piaui
# Processing record 419|conde
# Processing record 420|piacabucu
# Processing record 421|hervey bay
# Processing record 422|whangarei
# Processing record 423|saint-joseph
# Processing record 424|jequie
# Processing record 425|moranbah
# Processing record 426|namibe
# Processing record 427|rio verde de mato grosso
# Processing record 428|popondetta
# Processing record 429|tadine
# Processing record 430|general roca
# Processing record 431|indramayu
# Processing record 432|hualmay
# Processing record 433|oudtshoorn
# Processing record 434|bundaberg
# Processing record 435|mariakani
# Processing record 436|namatanai
# Processing record 437|santiago
# Processing record 438|port macquarie
# Processing record 439|samarai
# Processing record 440|cap malheureux
# Processing record 441|itaituba
# Processing record 442|kununurra
# City is not found. skipping.
# Processing record 443|nata
# Processing record 444|port keats
# Processing record 445|waipawa
# Processing record 446|avera
# Processing record 447|papara
# Processing record 448|talcahuano
# Processing record 449|kokopo
# Processing record 450|san rafael
# Processing record 451|huarmey
# Processing record 452|bulawayo
# Processing record 453|san vicente
# Processing record 454|guaruja
# Processing record 455|pitimbu
# Processing record 456|comodoro rivadavia
# Processing record 457|angoche
# Processing record 458|rio gallegos
# Processing record 459|xai-xai
# Processing record 460|whyalla
# Processing record 461|pailon
# Processing record 462|prainha
# Processing record 463|alvaraes
# Processing record 464|richards bay
# Processing record 465|plettenberg bay
# Processing record 466|palembang
# Processing record 467|takoradi
# Processing record 468|moerai
# Processing record 469|oranjemund
# Processing record 470|ambatolampy
# Processing record 471|cairns
# Processing record 472|palora
# Processing record 473|geelong
# Processing record 474|kiama
# Processing record 475|ballina
# Processing record 476|beloha
# Processing record 477|cavalcante
# Processing record 478|ahipara
# Processing record 479|songea
# Processing record 480|abaetetuba
# Processing record 481|gorontalo
# Processing record 482|pangkalanbuun
# Processing record 483|correia pinto
# City is not found. skipping.
# Processing record 484|ambilobe
# Processing record 485|asau
# Processing record 486|ipixuna
# Processing record 487|moree
# Processing record 488|margate
# Processing record 489|bambanglipuro
# Processing record 490|antanifotsy
# Processing record 491|nabire
# Processing record 492|santa rosa
# Processing record 493|corrente
# Processing record 494|padang
# Processing record 495|manggar
# Processing record 496|victor harbor
# Processing record 497|cabedelo
# Processing record 498|murray bridge
# Processing record 499|nhulunbuy
# Processing record 500|mataram
# Processing record 501|lufilufi
# City is not found. skipping.
# Processing record 502|chilca
# Processing record 503|broome
# Processing record 504|calama
# Processing record 505|henties bay
# Processing record 506|auki
# Processing record 507|honiara
# Processing record 508|oriximina
# Processing record 509|oxapampa
# City is not found. skipping.
# Processing record 510|cassilandia
# Processing record 511|keetmanshoop
# Processing record 512|ulladulla
# Processing record 513|lamu
# Processing record 514|ituacu
# City is not found. skipping.
# Processing record 515|sechura
# Processing record 516|america dourada
# Processing record 517|xique-xique
# Processing record 518|kibala
# Processing record 519|otjimbingwe
# Processing record 520|kipini
# Processing record 521|camacari
# Processing record 522|antsohihy
# Processing record 523|broken hill
# Processing record 524|gurupi
# Processing record 525|eten
# Processing record 526|saint-denis
# Processing record 527|port moresby
# City is not found. skipping.
# Processing record 528|junqueiropolis
# City is not found. skipping.
# Processing record 529|madang
# Processing record 530|cauquenes
# Processing record 531|morondava
# Processing record 532|gizo
# City is not found. skipping.
# Processing record 533|lusambo
# Processing record 534|luganville
# Processing record 535|manicore
# Processing record 536|rocha
# Processing record 537|itororo
# Processing record 538|saint-leu
# Processing record 539|maceio
# Processing record 540|mitu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City":cityname, 
                        "Lat":lat,
                        "Lng":lon,
                        "Max Temp":tempmax,
                        "Humidity":humidity,
                        "Cloudiness":clouds, 
                        "Wind Speed":windspeed,
                        "Country":country, 
                        "Date":date})

#Exporting data to csv
weather_df.to_csv(f'../{output_data_file}',index=False)

print(f' There is a total of {len(weather_df.index)} rows of values are contained in this DataFrame')

#Displaying dataframe
weather_df.head()
# Out:
#  There is a total of 540 rows of values are contained in this DataFrame
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Khatanga  71.9667  102.5000     -2.42        95         100       11.43
# 1   Deer Lake  49.1667  -57.4316     19.26        73         100        8.05
# 2     Kavieng  -2.5744  150.7967     85.87        64           9       13.20
# 3      Barrow  71.2906 -156.7887      1.42        78         100       13.80
# 4  Butaritari   3.0707  172.7902     81.66        72           4       19.71
#
#   Country        Date
# 0      RU  1647225550
# 1      CA  1647225550
# 2      PG  1647225551
# 3      US  1647225551
# 4      KI  1647225551

# %%
Count=[]
Mean=[]
Std=[]
Min=[]
Max=[]
Lowerq =[]
Mediq=[]
Upperq =[]

column_name = weather_df.columns.tolist()
for x in column_name:
    try: 
        Mean.append(weather_df[x].mean())
        Count.append(weather_df[x].count())
        Std.append(weather_df[x].std())
        Min.append(weather_df[x].min())
        Max.append(weather_df[x].max())
        Lowerq.append(weather_df[x].quantile(.25))
        Mediq.append(weather_df[x].quantile(.5))
        Upperq.append(weather_df[x].quantile(.75))


    except TypeError:
        Mean=Mean
        Count=Count
        Std=Std
        Min=Min
        Max=Max
        Lowerq=Lowerq
        Mediq=Mediq
        Upperq=Upperq
        
all_rows = [Count,Mean,Std,Min,Lowerq,Mediq,Upperq,Max]
Summary_df = pd.DataFrame(all_rows, columns=['Lat', 'Lng',"Max Temp","Humidity","Cloudiness","Wind Speed","Date"],
                  index=['count', 'mean',"std","min","25%","50%","75%","max"])
Summary_df
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  540.000000  540.000000  540.000000  540.000000  540.000000  540.000000
# mean    11.227451   14.197779   58.517944   72.342593   59.105556    7.400685
# std     33.811735   92.303403   26.583189   20.878108   39.316163    5.481148
# min    -54.800000 -179.166700  -27.540000    1.000000    0.000000    0.000000
# 25%    -18.717025  -63.370850   43.910000   62.000000   20.000000    3.440000
# 50%      5.538950   17.380450   68.790000   76.000000   75.000000    5.930000
# 75%     40.804075  100.199975   78.160000   88.000000  100.000000    9.685000
# max     78.218600  178.416700   97.050000  100.000000  100.000000   36.820000
#
#                Date
# count  5.400000e+02
# mean   1.647226e+09
# std    7.331048e+01
# min    1.647225e+09
# 25%    1.647226e+09
# 50%    1.647226e+09
# 75%    1.647226e+09
# max    1.647226e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%. <br>
# ___From the above DataFrame,the maximum of humidity is 100%.___<br>
# ___Therefore, no no cities that have humidity > 100%___ <br>
# ___This step is skipped.___

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# The equator has the highest temperature, and the temperature gradually decreases as it moves along the equator towards the earth's poles.<br/>

# %%
# %matplotlib notebook
import datetime

today = time.strftime("%m/%d/%Y")
LatitudeTemperature = weather_df.loc[(weather_df["Date"] == 1646986138)]
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Max Temp"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Latitude vs. Max Temperature ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Temperature (Max).png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# There is no obvious correlation between the two variables.<br/>
# But, when the latitude is between 0 to 20, the humidity is the lowest.<br/>
# Afterwards, as the latitude moves to the sides, the humidity gradually increases.<br/>

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Humidity"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Latitude vs. Humidity ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# There is no obvious correlation between the two variables.<br/>
# But cloud cover appears to be centered around 0% and 100%.<br/>
# And in the middle part, the plot has a certain concentration in the 20%, 40% and 75% parts.<br/>

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness (%)")
plt.title(f"Latitude vs. Cloudiness ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# There is no obvious correlation between the two variables.<br/>
# But for most cities, they have wind speeds between 0-20 mph.<br/>

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Latitude vs. Wind Speed ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Wind Speed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Linear Regression

# %%
northern_df = weather_df.loc[weather_df["Lat"].astype(float) >=0]
southern_df = weather_df.loc[weather_df["Lat"].astype(float) <=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is -0.89, which means that there is a very strong negative correlation between Max Temp Latitude in the Northern Hemisphere.<br/>
# Temperature decreases with the increase of latitude.<br/>
# Typically:<br/>
# 1.0  = |R|         - Perfect positive/negative correlation<br/>
# 0.8 <= |R| < 1.0   - Very strong positive/negative correlated.<br/>
# 0.6 <= |R| < 0.8   - Strong positive/negative correlated.<br/>
# 0.4 <= |R| < 0.6   - Moderate positive/negative correlated.<br/>
# 0.2 <= |R| < 0.4   - Weak positive/negative correlated.<br/>
# 0.0 <= |R| < 0.2   - Very weak positive/negative correlated.<br/>
# 0.0  = |R|         - No correlated.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(5,5),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Northern Hemisphere - Max Temp vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: -0.8897349711934301

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.50, which means that there is a moderate positive correlation between Max Temp and Latitude in the Southern Hemisphere.<br/>
# Temperature increase with the increase of latitude.<br/>
# This Description matches to the conclusion drawn from the plot `"Latitude vs. Temperature (Max)"` - Besides latitude, the high coverage of surface water is another factor that affects temperatures in Southern Hemisphere.
# Therefore, the correlation between Max Temp and Latitude in the Southern Hemisphere is not as strong as it in Northern Hemisphere.

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,75),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()


# Save the chart
plt.savefig("../output_WeatherPy/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.5040037224949631

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.30, which means that there is a weak positive correlation between Humidity and Latitude in the Northern Hemisphere.<br/>
# Humidity increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(40,10),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere - Humidity (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.2997504260921686

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.36, which means a weak positive correlation between Humidity and Latitude in the Southern Hemisphere. And it is even weaker in Southern Hemisphere than it is in Northern Hemisphere.<br/>
# Humidity increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,35),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.362501936457663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.17, which means that there is a very weak positive correlation between Cloudiness and Latitude in the Northern Hemisphere.<br/>
# Cloudiness increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(45,30),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness(%)")
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.17239858702529287

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.35, which means that there is a weak positive correlation between Cloudiness and Latitude in the Southern Hemisphere. And it is stronger in Southern Hemisphere than it is in Northern Hemisphere.<br/>
# Cloudiness increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,63),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness(%)")
plt.title(f"Sorthern Hemisphere - Cloudiness (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Sorthern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.34530894190034794

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.11, which means that there is a very weak positive correlation between Wind Speed and Latitude in the Northern Hemisphere.<br/>
# Wind Speed increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(0,35),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed(mph)")
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.11056980283668871

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is -0.39, which means that there is a weak negative correlation between Wind Speed and Latitude in the Southern Hemisphere. And it is stronger in Southern Hemisphere than it is in Northern Hemisphere. But the linear regression goes to the opposite direction, negative instead of positive.<br/>
# Wind Speed decreade with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,17.5),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed(mph)")
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: -0.394088036023727
