# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
north_lat_lngs = []
north_cities = []
south_cities =[]

# Create a set of random lat and lng combinations
north_lats = np.random.uniform(low=0, high=90.000, size=600)
north_lngs = np.random.uniform(low=-180.000, high=180.000, size=600)
north_lat_lngs = zip(north_lats, north_lngs)

# Identify nearest city for each lat, lng combination
for north_lat_lng in north_lat_lngs:
    north_city = citipy.nearest_city(north_lat_lng[0], north_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if north_city not in north_cities:
        north_cities.append(north_city)

# Create a set of random lat and lng combinations
south_lats = np.random.uniform(low=-90.000, high=0, size=1600)
south_lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
south_lat_lngs = zip(south_lats, south_lngs)

# Identify nearest city for each lat, lng combination
for south_lat_lng in south_lat_lngs:
    south_city = citipy.nearest_city(south_lat_lng[0], south_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if south_city not in south_cities:
        south_cities.append(south_city)
        
# Print the city count to confirm sufficient count
print(f'Exported {len(north_cities)} cities in the Northern Hemisphere')
print(f'Exported {len(south_cities)} cities in the Northern Hemisphere')
# Out:
# Exported 360 cities in the Northern Hemisphere
# Exported 304 cities in the Northern Hemisphere

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
clouds = []
country = []
date = []
tempmax = []
humidity = []
lat = []
lon = []
windspeed = []
cityname = []

# use loop to get all the column value.
# use try to exclusive the city that can't be found.

#doesn't mention the task relate to temperate history. Therefore, use the current API.
k=1
for city in north_cities:
    if len(cityname)<270:
        units="imperial"
        url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
        weater_detail = requests.get(url_weater).json()
        try: 
            clouds.append(weater_detail["clouds"]["all"])
            country.append(weater_detail["sys"]["country"])
            date.append(weater_detail["dt"])
            tempmax.append(weater_detail["main"]['temp_max'])
            humidity.append(weater_detail["main"]['humidity'])
            lat.append(weater_detail["coord"]["lat"])  
            lon.append(weater_detail["coord"]["lon"])
            windspeed.append(weater_detail["wind"]["speed"])
            cityname.append(weater_detail["name"])
            print(f"Processing record {k}|{city}")
            k+=1
        except (KeyError):
            print("City is not found. skipping.")

for city in south_cities:
    if len(cityname)<540:
        units="imperial"
        url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
        weater_detail = requests.get(url_weater).json()
        try: 
            clouds.append(weater_detail["clouds"]["all"])
            country.append(weater_detail["sys"]["country"])
            date.append(weater_detail["dt"])
            tempmax.append(weater_detail["main"]['temp_max'])
            humidity.append(weater_detail["main"]['humidity'])
            lat.append(weater_detail["coord"]["lat"])  
            lon.append(weater_detail["coord"]["lon"])
            windspeed.append(weater_detail["wind"]["speed"])
            cityname.append(weater_detail["name"])
            print(f"Processing record {k}|{city}")
            k+=1
        except (KeyError):
            print("City is not found. skipping.")
# Out:
# City is not found. skipping.
# Processing record 1|thompson
# Processing record 2|killarney
# Processing record 3|ilulissat
# Processing record 4|tuktoyaktuk
# Processing record 5|narsaq
# Processing record 6|aklavik
# Processing record 7|qasigiannguit
# Processing record 8|songjianghe
# Processing record 9|kapaa
# City is not found. skipping.
# Processing record 10|half moon bay
# Processing record 11|cherskiy
# Processing record 12|tumaco
# Processing record 13|severo-yeniseyskiy
# Processing record 14|ciudad bolivar
# Processing record 15|karpogory
# City is not found. skipping.
# Processing record 16|chowchilla
# Processing record 17|lasa
# Processing record 18|tasiilaq
# Processing record 19|sebinkarahisar
# Processing record 20|baruun-urt
# Processing record 21|butaritari
# Processing record 22|acajutla
# Processing record 23|linjiang
# Processing record 24|nazas
# Processing record 25|bonthe
# Processing record 26|sao filipe
# Processing record 27|turukhansk
# Processing record 28|olafsvik
# Processing record 29|dikson
# Processing record 30|cayenne
# Processing record 31|saskylakh
# City is not found. skipping.
# Processing record 32|lagoa
# Processing record 33|kavaratti
# Processing record 34|jinji
# Processing record 35|yankton
# City is not found. skipping.
# Processing record 36|lyudinovo
# Processing record 37|nouadhibou
# Processing record 38|ribeira grande
# Processing record 39|sur
# Processing record 40|la baule-escoublac
# Processing record 41|chokurdakh
# Processing record 42|andreapol
# Processing record 43|longyearbyen
# Processing record 44|simao
# Processing record 45|polyarnyy
# Processing record 46|arlit
# Processing record 47|bathsheba
# Processing record 48|kurumkan
# City is not found. skipping.
# Processing record 49|buckeye
# Processing record 50|shubarkuduk
# Processing record 51|qaanaaq
# Processing record 52|shagamu
# Processing record 53|the pas
# Processing record 54|barrow
# Processing record 55|mogocha
# Processing record 56|bandiagara
# City is not found. skipping.
# Processing record 57|klaksvik
# Processing record 58|nanortalik
# Processing record 59|siilinjarvi
# Processing record 60|vila franca do campo
# Processing record 61|yellowknife
# Processing record 62|sitka
# Processing record 63|airai
# Processing record 64|iqaluit
# Processing record 65|pangnirtung
# City is not found. skipping.
# City is not found. skipping.
# Processing record 66|roald
# Processing record 67|manaure
# Processing record 68|atuona
# Processing record 69|san marcos
# Processing record 70|loreto
# Processing record 71|kodiak
# Processing record 72|tiksi
# Processing record 73|batagay-alyta
# Processing record 74|svetlogorsk
# Processing record 75|lyubar
# Processing record 76|ucluelet
# Processing record 77|impfondo
# Processing record 78|jumla
# Processing record 79|superior
# Processing record 80|ajdabiya
# City is not found. skipping.
# Processing record 81|beringovskiy
# Processing record 82|cabo san lucas
# Processing record 83|hilo
# Processing record 84|khlung
# City is not found. skipping.
# City is not found. skipping.
# Processing record 85|lorengau
# City is not found. skipping.
# Processing record 86|abu samrah
# City is not found. skipping.
# Processing record 87|nikolskoye
# Processing record 88|tvrdosin
# Processing record 89|ulaangom
# Processing record 90|zurrieq
# Processing record 91|torbay
# Processing record 92|suntar
# City is not found. skipping.
# Processing record 93|celestun
# Processing record 94|bettiah
# City is not found. skipping.
# Processing record 95|matane
# Processing record 96|brownwood
# City is not found. skipping.
# Processing record 97|gombe
# Processing record 98|kenai
# Processing record 99|upernavik
# Processing record 100|tayoltita
# Processing record 101|constitucion
# Processing record 102|juba
# Processing record 103|paamiut
# Processing record 104|zhangye
# Processing record 105|bubaque
# Processing record 106|dunmore east
# Processing record 107|hasaki
# Processing record 108|saint-pierre
# Processing record 109|porlamar
# Processing record 110|toba
# Processing record 111|thinadhoo
# Processing record 112|alexandria
# Processing record 113|pell city
# Processing record 114|tongliao
# Processing record 115|concepcion del oro
# Processing record 116|abu kamal
# Processing record 117|ankang
# Processing record 118|port hardy
# Processing record 119|bandarbeyla
# Processing record 120|north bend
# Processing record 121|sisimiut
# Processing record 122|green river
# Processing record 123|seoul
# Processing record 124|marzuq
# Processing record 125|tallahassee
# Processing record 126|mehamn
# Processing record 127|makakilo city
# City is not found. skipping.
# Processing record 128|zyryanka
# Processing record 129|santa marta
# Processing record 130|codrington
# Processing record 131|nemuro
# Processing record 132|sompeta
# Processing record 133|tottori
# Processing record 134|bilma
# Processing record 135|khatanga
# Processing record 136|takoradi
# Processing record 137|hue
# City is not found. skipping.
# Processing record 138|kutum
# Processing record 139|ostrovnoy
# City is not found. skipping.
# Processing record 140|koshurnikovo
# Processing record 141|leningradskiy
# Processing record 142|fort nelson
# Processing record 143|vostok
# Processing record 144|dingle
# Processing record 145|shitanjing
# Processing record 146|aguilas
# Processing record 147|gambela
# Processing record 148|carutapera
# Processing record 149|pingdingshan
# Processing record 150|kurchum
# Processing record 151|praia da vitoria
# Processing record 152|camacha
# Processing record 153|sao gabriel da cachoeira
# Processing record 154|kieta
# Processing record 155|tongchuan
# Processing record 156|bilibino
# Processing record 157|slonim
# Processing record 158|freeport
# Processing record 159|adrar
# Processing record 160|bethel
# Processing record 161|balaipungut
# Processing record 162|fortuna
# Processing record 163|enshi
# Processing record 164|bure
# Processing record 165|college
# Processing record 166|visby
# Processing record 167|ponta do sol
# Processing record 168|palimbang
# Processing record 169|victoria
# Processing record 170|norman wells
# City is not found. skipping.
# Processing record 171|yilan
# Processing record 172|marsala
# Processing record 173|goderich
# Processing record 174|inta
# Processing record 175|trezzano sul naviglio
# Processing record 176|zykovo
# City is not found. skipping.
# Processing record 177|acarau
# Processing record 178|moose factory
# City is not found. skipping.
# City is not found. skipping.
# Processing record 179|jiangyou
# Processing record 180|trabzon
# Processing record 181|verona
# Processing record 182|shingu
# Processing record 183|havre
# Processing record 184|lashio
# Processing record 185|talaya
# Processing record 186|vestmannaeyjar
# Processing record 187|pevek
# Processing record 188|matale
# Processing record 189|xiongzhou
# Processing record 190|provideniya
# Processing record 191|lavrentiya
# Processing record 192|newport
# Processing record 193|weyburn
# Processing record 194|minab
# Processing record 195|tura
# Processing record 196|komsomolskiy
# Processing record 197|tiznit
# Processing record 198|nivala
# Processing record 199|kishi
# Processing record 200|kankon
# City is not found. skipping.
# Processing record 201|belturbet
# Processing record 202|brainerd
# Processing record 203|saltpond
# Processing record 204|lompoc
# City is not found. skipping.
# Processing record 205|tabou
# Processing record 206|severo-kurilsk
# City is not found. skipping.
# Processing record 207|anadyr
# City is not found. skipping.
# Processing record 208|havoysund
# Processing record 209|fairbanks
# Processing record 210|paka
# Processing record 211|dixon
# Processing record 212|storforshei
# Processing record 213|saint george
# Processing record 214|los llanos de aridane
# Processing record 215|khani
# Processing record 216|kalaleh
# Processing record 217|rorvik
# City is not found. skipping.
# Processing record 218|zaragoza
# Processing record 219|falkenstein
# Processing record 220|derac
# Processing record 221|alugan
# Processing record 222|rawah
# Processing record 223|san patricio
# Processing record 224|palmer
# Processing record 225|huescar
# Processing record 226|businga
# Processing record 227|martinsville
# Processing record 228|port hawkesbury
# Processing record 229|cap estate
# Processing record 230|atbasar
# Processing record 231|sibolga
# Processing record 232|mayo
# Processing record 233|yatou
# Processing record 234|fairmont
# Processing record 235|mrakovo
# Processing record 236|coos bay
# Processing record 237|abu dhabi
# Processing record 238|wagar
# Processing record 239|lovington
# Processing record 240|west wendover
# Processing record 241|puerto escondido
# City is not found. skipping.
# Processing record 242|katsuura
# Processing record 243|acapulco
# Processing record 244|aldan
# Processing record 245|omsukchan
# Processing record 246|abilene
# Processing record 247|valley city
# Processing record 248|shymkent
# Processing record 249|buchanan
# Processing record 250|san quintin
# Processing record 251|grindavik
# Processing record 252|lucani
# Processing record 253|kuching
# City is not found. skipping.
# Processing record 254|trairi
# Processing record 255|mezen
# Processing record 256|monroe
# Processing record 257|san mateo del mar
# Processing record 258|preobrazheniye
# City is not found. skipping.
# Processing record 259|mandalgovi
# Processing record 260|trincomalee
# Processing record 261|karakol
# Processing record 262|ithaca
# Processing record 263|san andres
# Processing record 264|puerto ayora
# City is not found. skipping.
# Processing record 265|moron
# Processing record 266|pavlovsk
# Processing record 267|high rock
# Processing record 268|dangriga
# City is not found. skipping.
# City is not found. skipping.
# Processing record 269|baiyin
# Processing record 270|santa cruz
# Processing record 271|jamestown
# Processing record 272|hermanus
# Processing record 273|albany
# Processing record 274|punta arenas
# Processing record 275|mataura
# Processing record 276|avarua
# Processing record 277|mar del plata
# Processing record 278|sechura
# Processing record 279|hobart
# Processing record 280|puerto ayora
# Processing record 281|pandamatenga
# Processing record 282|itacarambi
# Processing record 283|cap malheureux
# Processing record 284|rikitea
# Processing record 285|busselton
# Processing record 286|new norfolk
# City is not found. skipping.
# Processing record 287|ushuaia
# City is not found. skipping.
# Processing record 288|east london
# Processing record 289|chuy
# Processing record 290|vaini
# Processing record 291|atuona
# Processing record 292|lebu
# Processing record 293|luwuk
# City is not found. skipping.
# Processing record 294|saint-philippe
# Processing record 295|comodoro rivadavia
# Processing record 296|rio gallegos
# Processing record 297|bengkulu
# Processing record 298|saint-joseph
# Processing record 299|alice springs
# Processing record 300|cape town
# Processing record 301|bluff
# Processing record 302|conde
# Processing record 303|viedma
# Processing record 304|tucurui
# City is not found. skipping.
# Processing record 305|necochea
# Processing record 306|castro
# Processing record 307|katima mulilo
# Processing record 308|port elizabeth
# Processing record 309|pemba
# Processing record 310|faanui
# Processing record 311|bredasdorp
# Processing record 312|soe
# Processing record 313|chapada dos guimaraes
# Processing record 314|coquimbo
# City is not found. skipping.
# Processing record 315|lodja
# Processing record 316|cairns
# City is not found. skipping.
# City is not found. skipping.
# Processing record 317|kamina
# City is not found. skipping.
# Processing record 318|imbituba
# Processing record 319|arraial do cabo
# Processing record 320|coihaique
# Processing record 321|sokoni
# Processing record 322|kununurra
# Processing record 323|carnarvon
# Processing record 324|esperance
# Processing record 325|santiago
# Processing record 326|saldanha
# Processing record 327|vilhena
# Processing record 328|inhambane
# Processing record 329|havelock
# Processing record 330|namibe
# Processing record 331|pisco
# Processing record 332|mazabuka
# Processing record 333|georgetown
# Processing record 334|ahipara
# Processing record 335|vao
# Processing record 336|menongue
# Processing record 337|hualmay
# Processing record 338|tuatapere
# Processing record 339|acari
# Processing record 340|axim
# Processing record 341|chiredzi
# City is not found. skipping.
# Processing record 342|port alfred
# Processing record 343|wewak
# Processing record 344|plettenberg bay
# Processing record 345|burnie
# City is not found. skipping.
# Processing record 346|cidreira
# Processing record 347|coruripe
# Processing record 348|bambous virieux
# Processing record 349|portland
# Processing record 350|likasi
# Processing record 351|tiarei
# Processing record 352|ancud
# Processing record 353|port macquarie
# Processing record 354|ipixuna
# Processing record 355|koster
# Processing record 356|nhulunbuy
# Processing record 357|mahebourg
# Processing record 358|kieta
# Processing record 359|mount gambier
# Processing record 360|guaruja
# Processing record 361|san antonio
# Processing record 362|olinda
# Processing record 363|kaitangata
# Processing record 364|manggar
# Processing record 365|aripuana
# Processing record 366|carauari
# Processing record 367|porto velho
# Processing record 368|iquique
# Processing record 369|yulara
# City is not found. skipping.
# Processing record 370|launceston
# Processing record 371|hithadhoo
# Processing record 372|tacuarembo
# Processing record 373|bima
# City is not found. skipping.
# Processing record 374|maumere
# Processing record 375|mildura
# Processing record 376|ilo
# Processing record 377|takaka
# Processing record 378|porto belo
# Processing record 379|auki
# Processing record 380|colquechaca
# Processing record 381|walvis bay
# Processing record 382|mafinga
# Processing record 383|merauke
# Processing record 384|victoria
# Processing record 385|ballina
# Processing record 386|port-gentil
# Processing record 387|grand gaube
# Processing record 388|kruisfontein
# Processing record 389|cabedelo
# Processing record 390|neuquen
# Processing record 391|mount isa
# Processing record 392|morondava
# Processing record 393|margate
# Processing record 394|quatre cocos
# Processing record 395|oranjemund
# Processing record 396|luderitz
# Processing record 397|rawson
# Processing record 398|broome
# Processing record 399|sola
# Processing record 400|waipawa
# Processing record 401|bahia blanca
# Processing record 402|vrede
# Processing record 403|voi
# Processing record 404|soyo
# Processing record 405|pujili
# Processing record 406|katete
# Processing record 407|george
# Processing record 408|northam
# Processing record 409|ambulu
# Processing record 410|namatanai
# Processing record 411|angoche
# City is not found. skipping.
# Processing record 412|ponerihouen
# Processing record 413|boyolangu
# Processing record 414|lano
# Processing record 415|luanda
# Processing record 416|karratha
# Processing record 417|waingapu
# Processing record 418|henties bay
# City is not found. skipping.
# Processing record 419|sumbawanga
# Processing record 420|isangel
# Processing record 421|takoradi
# Processing record 422|borba
# Processing record 423|asau
# Processing record 424|upington
# Processing record 425|kapiri mposhi
# Processing record 426|autazes
# Processing record 427|san cristobal
# Processing record 428|vila velha
# Processing record 429|puerto quijarro
# Processing record 430|bowen
# Processing record 431|lata
# Processing record 432|colac
# Processing record 433|santa fe
# Processing record 434|conceicao do araguaia
# Processing record 435|balfour
# Processing record 436|daru
# Processing record 437|mutoko
# Processing record 438|padang
# Processing record 439|geraldton
# Processing record 440|vila
# Processing record 441|rioja
# Processing record 442|chicama
# City is not found. skipping.
# Processing record 443|hamilton
# Processing record 444|alofi
# Processing record 445|ambovombe
# Processing record 446|flinders
# Processing record 447|reconquista
# Processing record 448|general roca
# Processing record 449|mount hagen
# Processing record 450|nabire
# Processing record 451|puerto leguizamo
# Processing record 452|souillac
# Processing record 453|lorengau
# Processing record 454|kandrian
# Processing record 455|san pedro
# Processing record 456|oriximina
# Processing record 457|dolores
# Processing record 458|goya
# City is not found. skipping.
# Processing record 459|kirakira
# Processing record 460|avera
# Processing record 461|lusambo
# Processing record 462|urucara
# Processing record 463|atambua
# Processing record 464|beloha
# Processing record 465|maragogi
# Processing record 466|melo
# Processing record 467|poum
# Processing record 468|liwale
# Processing record 469|saint-pierre
# Processing record 470|salto
# Processing record 471|uchiza
# Processing record 472|chopinzinho
# Processing record 473|te anau
# Processing record 474|santa rosa
# Processing record 475|matucana
# Processing record 476|garissa
# Processing record 477|kiama
# Processing record 478|talara
# Processing record 479|lavumisa
# Processing record 480|natal
# Processing record 481|camargo
# Processing record 482|kaoma
# Processing record 483|port shepstone
# Processing record 484|meulaboh
# City is not found. skipping.
# Processing record 485|port lincoln
# Processing record 486|ilave
# Processing record 487|general pico
# Processing record 488|quelimane
# Processing record 489|gizo
# Processing record 490|ascension
# City is not found. skipping.
# City is not found. skipping.
# Processing record 491|obidos
# Processing record 492|richards bay
# Processing record 493|labuhan
# Processing record 494|buala
# Processing record 495|sao jose da coroa grande
# Processing record 496|srandakan
# Processing record 497|ampanihy
# Processing record 498|mocuba
# Processing record 499|mareeba
# Processing record 500|tres passos
# Processing record 501|rafaela
# Processing record 502|matara
# Processing record 503|kasongo-lunda
# Processing record 504|letlhakane
# Processing record 505|kiunga
# Processing record 506|karasburg
# Processing record 507|mtwara
# Processing record 508|kupang
# Processing record 509|harper
# Processing record 510|planaltina
# Processing record 511|russell
# Processing record 512|paita
# Processing record 513|yeppoon
# City is not found. skipping.
# Processing record 514|maputo
# City is not found. skipping.
# Processing record 515|mmabatho
# Processing record 516|mbinga
# Processing record 517|piacabucu
# Processing record 518|chulucanas
# Processing record 519|popondetta
# Processing record 520|kaeo
# Processing record 521|iaciara
# Processing record 522|thinadhoo
# Processing record 523|omboue
# Processing record 524|micheweni
# Processing record 525|emerald
# Processing record 526|san joaquin
# Processing record 527|japura
# Processing record 528|tucuman
# Processing record 529|barreiros
# Processing record 530|bendigo
# Processing record 531|roebourne
# Processing record 532|pimentel
# Processing record 533|luwingu
# Processing record 534|dunedin
# Processing record 535|biak
# Processing record 536|barra do bugres
# Processing record 537|broken hill
# Processing record 538|malacacheta
# Processing record 539|southbridge
# Processing record 540|kyabram

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City":cityname, 
                        "Lat":lat,
                        "Lng":lon,
                        "Max Temp":tempmax,
                        "Humidity":humidity,
                        "Cloudiness":clouds, 
                        "Wind Speed":windspeed,
                        "Country":country, 
                        "Date":date})

#Exporting data to csv
weather_df.to_csv(f'../{output_data_file}')

print(f' There is a total of {len(weather_df.index)} rows of values are contained in this DataFrame')

#Displaying dataframe
weather_df.head()
# Out:
#  There is a total of 540 rows of values are contained in this DataFrame
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Thompson  55.7435  -97.8558    -19.08        95          61        6.98
# 1    Killarney  52.0500   -9.5167     51.19        77         100       10.22
# 2    Ilulissat  69.2167  -51.1000      3.22        51          75        2.30
# 3  Tuktoyaktuk  69.4541 -133.0374    -15.95        99         100        8.52
# 4       Narsaq  60.9167  -46.0500      5.22        71          62        2.19
#
#   Country        Date
# 0      CA  1647000747
# 1      IE  1647000747
# 2      GL  1647000747
# 3      CA  1647000747
# 4      GL  1647000748

# %%
Count=[]
Mean=[]
Std=[]
Min=[]
Max=[]
Lowerq =[]
Mediq=[]
Upperq =[]

column_name = weather_df.columns.tolist()
for x in column_name:
    try: 
        Mean.append(weather_df[x].mean())
        Count.append(weather_df[x].count())
        Std.append(weather_df[x].std())
        Min.append(weather_df[x].min())
        Max.append(weather_df[x].max())
        Lowerq.append(weather_df[x].quantile(.25))
        Mediq.append(weather_df[x].quantile(.5))
        Upperq.append(weather_df[x].quantile(.75))


    except TypeError:
        Mean=Mean
        Count=Count
        Std=Std
        Min=Min
        Max=Max
        Lowerq=Lowerq
        Mediq=Mediq
        Upperq=Upperq
        
all_rows = [Count,Mean,Std,Min,Lowerq,Mediq,Upperq,Max]
Summary_df = pd.DataFrame(all_rows, columns=['Lat', 'Lng',"Max Temp","Humidity","Cloudiness","Wind Speed","Date"],
                  index=['count', 'mean',"std","min","25%","50%","75%","max"])
Summary_df
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  540.000000  540.000000  540.000000  540.000000  540.000000  540.000000
# mean    10.889943   15.236907   59.836500   71.237037   59.216667    8.241685
# std     33.705080   91.055189   27.825713   21.130202   38.143359    6.228196
# min    -54.800000 -175.200000  -29.990000    6.000000    0.000000    0.000000
# 25%    -17.508325  -63.779875   45.620000   61.000000   20.000000    3.462500
# 50%      4.884500   18.181350   69.050000   76.000000   71.500000    6.910000
# 75%     40.613050  102.232425   80.152500   87.000000   99.000000   11.172500
# max     78.218600  179.316700  103.780000  100.000000  100.000000   35.790000
#
#                Date
# count  5.400000e+02
# mean   1.647001e+09
# std    6.912093e+01
# min    1.647000e+09
# 25%    1.647001e+09
# 50%    1.647001e+09
# 75%    1.647001e+09
# max    1.647001e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%. <br>
# ___From the above DataFrame,the maximum of humidity is 100%.___<br>
# ___Therefore, no no cities that have humidity > 100%___ <br>
# ___This step is skipped.___

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# %matplotlib notebook
import datetime

today = time.strftime("%m/%d/%Y")
LatitudeTemperature = weather_df.loc[(weather_df["Date"] == 1646986138)]
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Max Temp"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Latitude vs. Max Temperature ({today})")
plt.show()

# Save the chart
plt.savefig("../output_data/Latitude vs. Temperature (Max).png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Humidity"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Latitude vs. Humidity ({today})")
plt.show()

# Save the chart
plt.savefig("../output_data/Latitude vs. Humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness (%)")
plt.title(f"Latitude vs. Cloudiness ({today})")
plt.show()

# Save the chart
plt.savefig("../output_data/Latitude vs. Cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Latitude vs. Wind Speed ({today})")
plt.show()

# Save the chart
plt.savefig("../output_data/Latitude vs. Wind Speed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Linear Regression

# %%
northern_df = weather_df.loc[weather_df["Lat"].astype(float) >0]
southern_df = weather_df.loc[weather_df["Lat"].astype(float) <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(5,5),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Northern Hemisphere - Max Temp vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: -0.8589364039466263

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,75),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()


# Save the chart
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.4831578097144663

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(40,10),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere - Humidity (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.3421653106643312

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,35),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.25082828675322716

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(45,30),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness(%)")
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.12866337914650075

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,63),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness(%)")
plt.title(f"Sorthern Hemisphere - Cloudiness (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Sorthern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.43864587799900207

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(0,35),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed(mph)")
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.08456381598458651

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,17.5),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed(mph)")
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: -0.3111344780476517
