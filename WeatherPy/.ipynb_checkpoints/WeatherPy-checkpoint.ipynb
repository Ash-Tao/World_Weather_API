# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
clouds = []
country = []
date = []
tempmax = []
humidity = []
lat = []
lon = []
windspeed = []
cityname = []

# use loop to get all the column value.
# use try to exclusive the city that can't be found.
k=1
for city in cities:
    units="imperial"
    url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
    weater_detail = requests.get(url_weater).json()
    try: 
        clouds.append(weater_detail["clouds"]["all"])
        country.append(weater_detail["sys"]["country"])
        date.append(weater_detail["dt"])
        tempmax.append(weater_detail["main"]['temp_max'])
        humidity.append(weater_detail["main"]['humidity'])
        lat.append(weater_detail["coord"]["lat"])  
        lon.append(weater_detail["coord"]["lon"])
        windspeed.append(weater_detail["wind"]["speed"])
        cityname.append(weater_detail["name"])
        print(f"Processing record {k}|{city}")
        k+=1
    except (KeyError):
        print("City is not found. skipping.")
# Out:
# Processing record 1|okhotsk
# Processing record 2|westport
# Processing record 3|sabang
# Processing record 4|geraldton
# Processing record 5|lyubech
# Processing record 6|albany
# Processing record 7|narsaq
# Processing record 8|dawei
# Processing record 9|troitskoye
# Processing record 10|komsomolskiy
# Processing record 11|sao joao da barra
# Processing record 12|poole
# Processing record 13|hilo
# Processing record 14|torbay
# Processing record 15|ushuaia
# Processing record 16|alekseyevka
# Processing record 17|kapaa
# City is not found. skipping.
# City is not found. skipping.
# Processing record 18|airai
# Processing record 19|kipini
# Processing record 20|ribeira grande
# Processing record 21|medina del campo
# Processing record 22|port elizabeth
# Processing record 23|dikson
# Processing record 24|punta arenas
# Processing record 25|cape town
# City is not found. skipping.
# City is not found. skipping.
# Processing record 26|esperance
# Processing record 27|aleksandrovsk-sakhalinskiy
# Processing record 28|katsuura
# Processing record 29|namibe
# Processing record 30|kalaleh
# Processing record 31|bartica
# Processing record 32|nizhniy kuranakh
# Processing record 33|rikitea
# Processing record 34|upernavik
# Processing record 35|faanui
# Processing record 36|khatanga
# Processing record 37|chara
# Processing record 38|cuxhaven
# Processing record 39|remuna
# Processing record 40|kamina
# Processing record 41|pevek
# Processing record 42|kavieng
# Processing record 43|leningradskiy
# City is not found. skipping.
# Processing record 44|saint-pierre
# Processing record 45|sola
# Processing record 46|san cristobal
# Processing record 47|butaritari
# Processing record 48|mataura
# City is not found. skipping.
# Processing record 49|ukiah
# Processing record 50|ankeny
# Processing record 51|muramatsu
# Processing record 52|vila franca do campo
# Processing record 53|ushtobe
# Processing record 54|mercedes
# Processing record 55|aasiaat
# Processing record 56|bluff
# Processing record 57|naliya
# Processing record 58|naantali
# Processing record 59|new norfolk
# Processing record 60|castro
# Processing record 61|kangalassy
# City is not found. skipping.
# Processing record 62|port hardy
# Processing record 63|vaini
# Processing record 64|rosarno
# Processing record 65|saint-augustin
# Processing record 66|constitucion
# Processing record 67|norman wells
# Processing record 68|bredasdorp
# City is not found. skipping.
# Processing record 69|thompson
# Processing record 70|hobart
# Processing record 71|jamestown
# Processing record 72|esna
# Processing record 73|kieta
# Processing record 74|tuktoyaktuk
# Processing record 75|durango
# Processing record 76|clyde river
# Processing record 77|severo-kurilsk
# Processing record 78|andenes
# City is not found. skipping.
# Processing record 79|nanortalik
# Processing record 80|sitka
# Processing record 81|grindavik
# Processing record 82|luderitz
# Processing record 83|mount isa
# Processing record 84|gornopravdinsk
# Processing record 85|kruisfontein
# City is not found. skipping.
# Processing record 86|mar del plata
# Processing record 87|asosa
# Processing record 88|kavaratti
# Processing record 89|busselton
# Processing record 90|talnakh
# Processing record 91|paracuru
# Processing record 92|san quintin
# Processing record 93|georgetown
# Processing record 94|cayenne
# Processing record 95|korsakov
# Processing record 96|portland
# Processing record 97|bambous virieux
# Processing record 98|ust-omchug
# Processing record 99|barrow
# Processing record 100|saint george
# Processing record 101|yerbogachen
# Processing record 102|turbat
# Processing record 103|aklavik
# Processing record 104|ulaangom
# Processing record 105|lebu
# Processing record 106|haines junction
# Processing record 107|cabo san lucas
# City is not found. skipping.
# Processing record 108|port alfred
# Processing record 109|avarua
# Processing record 110|cornwall
# City is not found. skipping.
# Processing record 111|cawayan
# Processing record 112|esso
# Processing record 113|kaitangata
# Processing record 114|hermanus
# Processing record 115|tiksi
# Processing record 116|longyearbyen
# Processing record 117|qaanaaq
# Processing record 118|chuy
# Processing record 119|atuona
# Processing record 120|gizo
# Processing record 121|lagoa
# Processing record 122|hasaki
# Processing record 123|port macquarie
# Processing record 124|cherskiy
# Processing record 125|paamiut
# Processing record 126|komsomolets
# City is not found. skipping.
# Processing record 127|birjand
# Processing record 128|puerto ayora
# Processing record 129|aykhal
# Processing record 130|touros
# Processing record 131|yellowknife
# Processing record 132|kodiak
# Processing record 133|faya
# Processing record 134|toktogul
# Processing record 135|roma
# Processing record 136|nadym
# Processing record 137|sangar
# Processing record 138|nyrob
# Processing record 139|pandan niog
# Processing record 140|chimore
# City is not found. skipping.
# Processing record 141|marzuq
# Processing record 142|olga
# Processing record 143|ahipara
# Processing record 144|taoudenni
# Processing record 145|santacruz
# Processing record 146|tazmalt
# Processing record 147|marystown
# Processing record 148|cabinda
# Processing record 149|alugan
# Processing record 150|wundanyi
# Processing record 151|mnogovershinnyy
# Processing record 152|vao
# Processing record 153|asau
# Processing record 154|klyuchi
# Processing record 155|fortuna
# Processing record 156|east london
# Processing record 157|progreso
# Processing record 158|merke
# Processing record 159|klaksvik
# Processing record 160|mount gambier
# Processing record 161|ewa beach
# Processing record 162|kailua
# Processing record 163|shenjiamen
# Processing record 164|esil
# Processing record 165|mehtar lam
# Processing record 166|provideniya
# Processing record 167|arraial do cabo
# Processing record 168|mahebourg
# Processing record 169|boa vista
# Processing record 170|chepareria
# City is not found. skipping.
# Processing record 171|olafsvik
# Processing record 172|tasiilaq
# Processing record 173|trelew
# Processing record 174|quatre cocos
# Processing record 175|nanakuli
# Processing record 176|pisco
# Processing record 177|karratha
# Processing record 178|fiumicino
# Processing record 179|yumen
# Processing record 180|la reforma
# City is not found. skipping.
# Processing record 181|saint-philippe
# Processing record 182|nantucket
# Processing record 183|mareeba
# Processing record 184|palmer
# Processing record 185|magog
# Processing record 186|dwarka
# Processing record 187|albanel
# Processing record 188|nikolskoye
# Processing record 189|xacmaz
# Processing record 190|bhavnagar
# Processing record 191|riyadh
# Processing record 192|rovnoye
# Processing record 193|vardo
# Processing record 194|anadyr
# Processing record 195|yuzhno-kurilsk
# Processing record 196|qui nhon
# Processing record 197|paris
# Processing record 198|victoria
# Processing record 199|alihe
# Processing record 200|henties bay
# Processing record 201|fare
# Processing record 202|rio grande
# Processing record 203|jalu
# Processing record 204|roald
# Processing record 205|te anau
# Processing record 206|nishihara
# Processing record 207|san patricio
# Processing record 208|zomin
# Processing record 209|deoli
# Processing record 210|yenagoa
# Processing record 211|aljezur
# Processing record 212|ergani
# Processing record 213|bauchi
# Processing record 214|ratnagiri
# Processing record 215|krasnozatonskiy
# Processing record 216|kearney
# Processing record 217|hithadhoo
# Processing record 218|karasburg
# Processing record 219|podgornoye
# City is not found. skipping.
# Processing record 220|saskylakh
# Processing record 221|singaraja
# Processing record 222|homer
# Processing record 223|kitimat
# Processing record 224|hit
# Processing record 225|broken hill
# Processing record 226|lorengau
# Processing record 227|souillac
# Processing record 228|lisakovsk
# Processing record 229|cocorit
# Processing record 230|yar-sale
# Processing record 231|juneau
# City is not found. skipping.
# Processing record 232|itarema
# Processing record 233|broome
# City is not found. skipping.
# Processing record 234|roebourne
# Processing record 235|mayumba
# City is not found. skipping.
# Processing record 236|borogontsy
# Processing record 237|lima
# Processing record 238|san lawrenz
# Processing record 239|deputatskiy
# Processing record 240|port blair
# Processing record 241|dingle
# Processing record 242|sioux lookout
# Processing record 243|ponta do sol
# Processing record 244|aswan
# Processing record 245|byron bay
# Processing record 246|vieques
# City is not found. skipping.
# Processing record 247|inongo
# Processing record 248|shakawe
# Processing record 249|bardsir
# Processing record 250|rocha
# Processing record 251|mae hong son
# Processing record 252|kungurtug
# Processing record 253|coihaique
# Processing record 254|tual
# Processing record 255|zhicheng
# Processing record 256|kamenka
# Processing record 257|bata
# Processing record 258|blagoyevo
# Processing record 259|alice springs
# City is not found. skipping.
# Processing record 260|kawalu
# Processing record 261|bilma
# Processing record 262|kemijarvi
# Processing record 263|cidreira
# Processing record 264|najran
# Processing record 265|santiago
# Processing record 266|seddon
# Processing record 267|port-gentil
# Processing record 268|floro
# Processing record 269|darhan
# Processing record 270|bethel
# Processing record 271|jamame
# Processing record 272|lazaro cardenas
# Processing record 273|dunedin
# Processing record 274|jackson
# Processing record 275|santander
# Processing record 276|vestmannaeyjar
# Processing record 277|miri
# Processing record 278|bhanvad
# Processing record 279|umm lajj
# Processing record 280|carnarvon
# Processing record 281|kalabo
# Processing record 282|ndola
# Processing record 283|straumen
# City is not found. skipping.
# Processing record 284|weligama
# Processing record 285|zyryanka
# Processing record 286|los llanos de aridane
# City is not found. skipping.
# Processing record 287|iqaluit
# City is not found. skipping.
# Processing record 288|acucena
# Processing record 289|polaniec
# Processing record 290|kedrovyy
# Processing record 291|coquimbo
# Processing record 292|iwanai
# Processing record 293|flin flon
# Processing record 294|la ronge
# Processing record 295|roros
# Processing record 296|jambi
# Processing record 297|pochutla
# Processing record 298|la paz
# Processing record 299|ise
# Processing record 300|tyret pervaya
# City is not found. skipping.
# Processing record 301|barranca
# Processing record 302|inhambane
# Processing record 303|labuhan
# Processing record 304|skjervoy
# Processing record 305|antofagasta
# City is not found. skipping.
# Processing record 306|grand gaube
# Processing record 307|katobu
# Processing record 308|nyurba
# Processing record 309|chokurdakh
# Processing record 310|marfino
# Processing record 311|baghdad
# Processing record 312|rio verde de mato grosso
# Processing record 313|nyuksenitsa
# Processing record 314|sao jose da coroa grande
# Processing record 315|bubaque
# Processing record 316|laguna
# Processing record 317|port lincoln
# Processing record 318|wilmington
# City is not found. skipping.
# Processing record 319|kambove
# Processing record 320|seymchan
# City is not found. skipping.
# Processing record 321|pandan
# Processing record 322|baker city
# Processing record 323|diego de almagro
# Processing record 324|khani
# Processing record 325|berbera
# Processing record 326|songea
# Processing record 327|balkanabat
# Processing record 328|awbari
# Processing record 329|son la
# Processing record 330|cozumel
# City is not found. skipping.
# Processing record 331|talcahuano
# Processing record 332|barmer
# Processing record 333|hindoria
# Processing record 334|yeppoon
# Processing record 335|tangermunde
# Processing record 336|boromlya
# Processing record 337|dyurtyuli
# Processing record 338|lengshuijiang
# Processing record 339|buenos aires
# Processing record 340|wanning
# Processing record 341|dharan
# Processing record 342|kokkola
# Processing record 343|turtas
# City is not found. skipping.
# Processing record 344|hunfeld
# Processing record 345|margate
# Processing record 346|gazanjyk
# Processing record 347|shache
# Processing record 348|constantine
# Processing record 349|tebingtinggi
# Processing record 350|cookeville
# City is not found. skipping.
# Processing record 351|prince rupert
# Processing record 352|praia da vitoria
# Processing record 353|beringovskiy
# Processing record 354|yulara
# Processing record 355|huambo
# Processing record 356|fiche
# Processing record 357|ilulissat
# Processing record 358|pointe michel
# Processing record 359|bonthe
# Processing record 360|ipora
# Processing record 361|ningbo
# Processing record 362|serov
# Processing record 363|angoche
# Processing record 364|horsham
# Processing record 365|shirakawa
# Processing record 366|garissa
# Processing record 367|oroville
# Processing record 368|saldanha
# Processing record 369|socorro
# Processing record 370|taltal
# Processing record 371|concepcion
# Processing record 372|tacuarembo
# Processing record 373|myitkyina
# Processing record 374|college
# Processing record 375|poum
# Processing record 376|kapustin yar
# Processing record 377|santa maria
# City is not found. skipping.
# Processing record 378|kuusamo
# Processing record 379|xam nua
# Processing record 380|salinas
# Processing record 381|aginskoye
# Processing record 382|nabire
# Processing record 383|rawson
# Processing record 384|mountain home
# Processing record 385|sabha
# Processing record 386|fuerte olimpo
# Processing record 387|hambantota
# Processing record 388|zhmerynka
# Processing record 389|pasighat
# Processing record 390|tezu
# Processing record 391|belmonte
# Processing record 392|san jose
# Processing record 393|mingyue
# Processing record 394|fomboni
# City is not found. skipping.
# Processing record 395|zhigansk
# Processing record 396|kahului
# Processing record 397|krasnoselkup
# Processing record 398|bengkulu
# Processing record 399|khandyga
# Processing record 400|buraydah
# Processing record 401|tombouctou
# Processing record 402|gorontalo
# Processing record 403|abha
# Processing record 404|estelle
# Processing record 405|harda
# Processing record 406|bangangte
# Processing record 407|nome
# Processing record 408|caravelas
# Processing record 409|villanueva
# City is not found. skipping.
# Processing record 410|hun
# Processing record 411|antalaha
# Processing record 412|simbahan
# Processing record 413|xichang
# Processing record 414|painesville
# Processing record 415|rafaela
# Processing record 416|mitsamiouli
# Processing record 417|kovdor
# City is not found. skipping.
# Processing record 418|naze
# Processing record 419|pangnirtung
# Processing record 420|coruripe
# Processing record 421|lasa
# Processing record 422|palembang
# Processing record 423|russell
# City is not found. skipping.
# Processing record 424|mporokoso
# Processing record 425|kurush
# Processing record 426|salta
# City is not found. skipping.
# Processing record 427|tilichiki
# Processing record 428|mayo
# Processing record 429|samarai
# Processing record 430|cabedelo
# Processing record 431|hamilton
# Processing record 432|havelock
# Processing record 433|rock springs
# Processing record 434|lipin bor
# Processing record 435|alofi
# Processing record 436|vermilion
# Processing record 437|dauphin
# Processing record 438|puerto escondido
# Processing record 439|sturgeon falls
# Processing record 440|san juan
# Processing record 441|srednekolymsk
# Processing record 442|birin
# Processing record 443|biak
# Processing record 444|acapulco
# Processing record 445|shingu
# Processing record 446|fort nelson
# Processing record 447|lata
# Processing record 448|sorland
# Processing record 449|qurayyat
# Processing record 450|cap-aux-meules
# Processing record 451|vievis
# Processing record 452|waitati
# City is not found. skipping.
# Processing record 453|flinders
# Processing record 454|itupiranga
# Processing record 455|diffa
# Processing record 456|maniitsoq
# Processing record 457|saint-francois
# Processing record 458|basco
# Processing record 459|hofn
# Processing record 460|macas
# Processing record 461|praia
# Processing record 462|lambarene
# Processing record 463|mormugao
# City is not found. skipping.
# Processing record 464|huarmey
# Processing record 465|huntington
# Processing record 466|zambezi
# City is not found. skipping.
# Processing record 467|acaponeta
# Processing record 468|san-pedro
# City is not found. skipping.
# Processing record 469|tshikapa
# Processing record 470|cockburn town
# Processing record 471|mackay
# Processing record 472|marsabit
# Processing record 473|paragominas
# City is not found. skipping.
# Processing record 474|amahai
# Processing record 475|puerto carreno
# Processing record 476|husavik
# Processing record 477|jasper
# Processing record 478|cao bang
# Processing record 479|cootamundra
# City is not found. skipping.
# City is not found. skipping.
# Processing record 480|solnechnyy
# Processing record 481|matagami
# Processing record 482|kattivakkam
# Processing record 483|hals
# Processing record 484|anloga
# Processing record 485|olinda
# Processing record 486|dovers
# Processing record 487|port hedland
# Processing record 488|sweetwater
# Processing record 489|gladstone
# Processing record 490|walvis bay
# Processing record 491|popondetta
# Processing record 492|bilibino
# Processing record 493|davila
# Processing record 494|nioki
# Processing record 495|montepuez
# Processing record 496|belogorsk
# Processing record 497|erenhot
# Processing record 498|pacific grove
# Processing record 499|charlestown
# City is not found. skipping.
# Processing record 500|biltine
# Processing record 501|churapcha
# Processing record 502|nemuro
# Processing record 503|blind river
# Processing record 504|pelym
# Processing record 505|conde
# Processing record 506|rio gallegos
# Processing record 507|fundao
# City is not found. skipping.
# Processing record 508|nhulunbuy
# Processing record 509|shepsi
# Processing record 510|ouegoa
# Processing record 511|ixtapa
# City is not found. skipping.
# Processing record 512|chicama
# Processing record 513|kirakira
# Processing record 514|joao pinheiro
# Processing record 515|mastic beach
# Processing record 516|tautira
# Processing record 517|tiarei
# Processing record 518|chernaya kholunitsa
# Processing record 519|burns lake
# Processing record 520|karasjok
# Processing record 521|frutal
# Processing record 522|kisaran
# Processing record 523|eureka
# City is not found. skipping.
# City is not found. skipping.
# Processing record 524|kormend
# Processing record 525|hovd
# Processing record 526|toyooka
# Processing record 527|brae
# City is not found. skipping.
# Processing record 528|yatou
# Processing record 529|orotukan
# Processing record 530|ayagoz
# Processing record 531|dickinson
# City is not found. skipping.
# Processing record 532|marlton
# Processing record 533|isangel
# Processing record 534|ranong
# Processing record 535|matara
# City is not found. skipping.
# Processing record 536|qom
# Processing record 537|chilca
# Processing record 538|storsteinnes
# City is not found. skipping.
# Processing record 539|ridgecrest
# Processing record 540|cody
# Processing record 541|shibetsu
# Processing record 542|menongue
# Processing record 543|ostrovnoy

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City":cityname, 
                        "Lat":lat,
                        "Lng":lon,
                        "Max Temp":tempmax,
                        "Humidity":humidity,
                        "Cloudiness":clouds, 
                        "Wind Speed":windspeed,
                        "Country":country, 
                        "Date":date})

#Exporting data to csv
weather_df.to_csv(f'../{output_data_file}')

print(f' There is a total of {len(weather_df.index)} rows of values are contained in this DataFrame')

#Displaying dataframe
weather_df.head()
# Out:
#  There is a total of 543 rows of values are contained in this DataFrame
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Okhotsk  59.3833  143.3000     19.62        92          71        5.35
# 1   Westport  41.1415  -73.3579     35.56        90           0        1.99
# 2     Sabang   5.8933   95.3214     82.31        71          92        4.70
# 3  Geraldton -28.7667  114.6000     84.61        58          36       13.80
# 4    Lyubech  51.7026   30.6569     24.82        50           4       15.32
#
#   Country        Date
# 0      RU  1646986138
# 1      US  1646986138
# 2      ID  1646986353
# 3      AU  1646986254
# 4      UA  1646986353

# %%
Count=[]
Mean=[]
Std=[]
Min=[]
Max=[]
Lowerq =[]
Mediq=[]
Upperq =[]

column_name = weather_df.columns.tolist()
for x in column_name:
    try: 
        Mean.append(weather_df[x].mean())
        Count.append(weather_df[x].count())
        Std.append(weather_df[x].std())
        Min.append(weather_df[x].min())
        Max.append(weather_df[x].max())
        Lowerq.append(weather_df[x].quantile(.25))
        Mediq.append(weather_df[x].quantile(.5))
        Upperq.append(weather_df[x].quantile(.75))


    except TypeError:
        Mean=Mean
        Count=Count
        Std=Std
        Min=Min
        Max=Max
        Lowerq=Lowerq
        Mediq=Mediq
        Upperq=Upperq
        
all_rows = [Count,Mean,Std,Min,Lowerq,Mediq,Upperq,Max]
Summary_df = pd.DataFrame(all_rows, columns=['Lat', 'Lng',"Max Temp","Humidity","Cloudiness","Wind Speed","Date"],
                  index=['count', 'mean',"std","min","25%","50%","75%","max"])
Summary_df
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  543.000000  543.000000  543.000000  543.000000  543.000000  543.000000
# mean    21.143996   19.486353   53.486133   71.132597   56.441989    8.323757
# std     33.610563   91.993406   29.691839   22.961160   41.352814    6.257217
# min    -54.800000 -175.200000  -26.990000    1.000000    0.000000    0.000000
# 25%     -8.107500  -65.117800   32.550000   61.500000    8.500000    3.780000
# 50%     26.002300   24.800000   60.820000   77.000000   68.000000    6.800000
# 75%     50.499950  101.299400   77.465000   88.000000  100.000000   11.500000
# max     78.218600  179.316700  104.670000  100.000000  100.000000   39.370000
#
#                Date
# count  5.430000e+02
# mean   1.646986e+09
# std    7.113625e+01
# min    1.646986e+09
# 25%    1.646986e+09
# 50%    1.646986e+09
# 75%    1.646986e+09
# max    1.646986e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%. <br>
# ___From the above DataFrame,the maximum of humidity is 100%.___<br>
# ___Therefore, no no cities that have humidity > 100%___ <br>
# ___This step is skipped.___

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
