# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_WeatherPy/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
north_lat_lngs = []
north_cities = []
south_cities =[]

# Create a set of random lat and lng combinations
north_lats = np.random.uniform(low=0, high=90.000, size=600)
north_lngs = np.random.uniform(low=-180.000, high=180.000, size=600)
north_lat_lngs = zip(north_lats, north_lngs)

# Identify nearest city for each lat, lng combination
for north_lat_lng in north_lat_lngs:
    north_city = citipy.nearest_city(north_lat_lng[0], north_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if north_city not in north_cities:
        north_cities.append(north_city)

# Create a set of random lat and lng combinations
south_lats = np.random.uniform(low=-90.000, high=0, size=1600)
south_lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
south_lat_lngs = zip(south_lats, south_lngs)

# Identify nearest city for each lat, lng combination
for south_lat_lng in south_lat_lngs:
    south_city = citipy.nearest_city(south_lat_lng[0], south_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if south_city not in south_cities:
        south_cities.append(south_city)
        
# Print the city count to confirm sufficient count
print(f'Exported {len(north_cities)} cities in the Northern Hemisphere')
print(f'Exported {len(south_cities)} cities in the Southern Hemisphere')
# Out:
# Exported 351 cities in the Northern Hemisphere
# Exported 316 cities in the Northern Hemisphere

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
clouds = []
country = []
date = []
tempmax = []
humidity = []
lat = []
lon = []
windspeed = []
cityname = []

# use loop to get all the column value.
# use try to exclusive the city that can't be found.

#doesn't mention the task relate to temperate history. Therefore, use the current API.
k=1
for city in north_cities:
    if len(cityname)<270:
        units="imperial"
        url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
        weater_detail = requests.get(url_weater).json()
        try: 
            clouds.append(weater_detail["clouds"]["all"])
            country.append(weater_detail["sys"]["country"])
            date.append(weater_detail["dt"])
            tempmax.append(weater_detail["main"]['temp_max'])
            humidity.append(weater_detail["main"]['humidity'])
            lat.append(weater_detail["coord"]["lat"])  
            lon.append(weater_detail["coord"]["lon"])
            windspeed.append(weater_detail["wind"]["speed"])
            cityname.append(weater_detail["name"])
            print(f"Processing record {k}|{city}")
            k+=1
        except (KeyError):
            print("City is not found. skipping.")

for city in south_cities:
    if len(cityname)<540:
        units="imperial"
        url_weater = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city}&units={units}"
        weater_detail = requests.get(url_weater).json()
        try: 
            clouds.append(weater_detail["clouds"]["all"])
            country.append(weater_detail["sys"]["country"])
            date.append(weater_detail["dt"])
            tempmax.append(weater_detail["main"]['temp_max'])
            humidity.append(weater_detail["main"]['humidity'])
            lat.append(weater_detail["coord"]["lat"])  
            lon.append(weater_detail["coord"]["lon"])
            windspeed.append(weater_detail["wind"]["speed"])
            cityname.append(weater_detail["name"])
            print(f"Processing record {k}|{city}")
            k+=1
        except (KeyError):
            print("City is not found. skipping.")
# Out:
# Processing record 1|slave lake
# Processing record 2|butaritari
# Processing record 3|anadyr
# Processing record 4|buraydah
# Processing record 5|clyde river
# Processing record 6|tasiilaq
# Processing record 7|shingu
# Processing record 8|tuktoyaktuk
# Processing record 9|chokurdakh
# Processing record 10|vardo
# Processing record 11|ponta delgada
# Processing record 12|barrow
# Processing record 13|ciresu
# City is not found. skipping.
# City is not found. skipping.
# City is not found. skipping.
# Processing record 14|sakakah
# Processing record 15|sokolo
# Processing record 16|murgab
# Processing record 17|airai
# Processing record 18|vestmannaeyjar
# Processing record 19|los llanos de aridane
# Processing record 20|suntar
# Processing record 21|port hardy
# Processing record 22|galbshtadt
# Processing record 23|nouadhibou
# Processing record 24|port blair
# Processing record 25|khatanga
# Processing record 26|leningradskiy
# Processing record 27|vostok
# Processing record 28|marystown
# Processing record 29|najran
# City is not found. skipping.
# City is not found. skipping.
# City is not found. skipping.
# Processing record 30|baracoa
# Processing record 31|yazman
# Processing record 32|les escoumins
# Processing record 33|wenling
# Processing record 34|tezu
# Processing record 35|bantogon
# Processing record 36|ostersund
# Processing record 37|vanimo
# Processing record 38|murree
# Processing record 39|flin flon
# Processing record 40|hasaki
# Processing record 41|lompoc
# Processing record 42|lavrentiya
# Processing record 43|kulebaki
# Processing record 44|mecca
# Processing record 45|pochutla
# Processing record 46|kenora
# Processing record 47|kapaa
# Processing record 48|cockburn town
# Processing record 49|lazaro cardenas
# Processing record 50|dikson
# Processing record 51|emilio carranza
# Processing record 52|celestun
# Processing record 53|sitka
# Processing record 54|itarema
# City is not found. skipping.
# Processing record 55|saint anthony
# Processing record 56|yellowknife
# Processing record 57|ribeira grande
# Processing record 58|sevsk
# Processing record 59|skelleftea
# Processing record 60|montorio al vomano
# Processing record 61|beaverlodge
# Processing record 62|san vicente
# Processing record 63|katsuura
# Processing record 64|kozhva
# Processing record 65|talnakh
# Processing record 66|khandagayty
# Processing record 67|tuy hoa
# Processing record 68|anaco
# Processing record 69|bethel
# Processing record 70|bereda
# Processing record 71|ponta do sol
# Processing record 72|preston
# Processing record 73|kodiak
# Processing record 74|mason city
# Processing record 75|namtsy
# Processing record 76|scottsbluff
# Processing record 77|provideniya
# Processing record 78|awjilah
# Processing record 79|atuona
# Processing record 80|lagoa
# Processing record 81|kavieng
# Processing record 82|nanortalik
# Processing record 83|sabha
# Processing record 84|zaozerne
# Processing record 85|hobyo
# Processing record 86|dmitriyevka
# Processing record 87|pagudpud
# Processing record 88|constitucion
# Processing record 89|grande prairie
# Processing record 90|kodinsk
# Processing record 91|sovetskiy
# Processing record 92|pierre
# Processing record 93|kushmurun
# Processing record 94|acapulco
# Processing record 95|soyaniquilpan
# Processing record 96|cabra
# Processing record 97|pevek
# Processing record 98|joshimath
# Processing record 99|adrar
# Processing record 100|shubarshi
# Processing record 101|albanel
# Processing record 102|qaanaaq
# Processing record 103|narsaq
# City is not found. skipping.
# Processing record 104|voyvozh
# Processing record 105|stornoway
# Processing record 106|longyan
# Processing record 107|nizhniy tsasuchey
# Processing record 108|kavaratti
# Processing record 109|cauas
# Processing record 110|sao gabriel da cachoeira
# Processing record 111|korla
# Processing record 112|okhotsk
# Processing record 113|jurado
# Processing record 114|jadu
# Processing record 115|palmer
# Processing record 116|jumla
# Processing record 117|sisimiut
# Processing record 118|thompson
# Processing record 119|nogliki
# Processing record 120|hilo
# Processing record 121|mattawa
# Processing record 122|itzehoe
# Processing record 123|fairbanks
# Processing record 124|bilma
# Processing record 125|jerome
# Processing record 126|harlingen
# Processing record 127|hot springs
# Processing record 128|gravdal
# Processing record 129|punto fijo
# Processing record 130|kifri
# Processing record 131|shakhunya
# Processing record 132|ejido
# Processing record 133|olafsvik
# Processing record 134|pacific grove
# Processing record 135|cayenne
# Processing record 136|nikolskoye
# Processing record 137|klaksvik
# Processing record 138|saint george
# Processing record 139|shimoda
# Processing record 140|yambio
# Processing record 141|neepawa
# City is not found. skipping.
# Processing record 142|galle
# Processing record 143|paamiut
# City is not found. skipping.
# Processing record 144|aklavik
# Processing record 145|mahuva
# Processing record 146|tiksi
# Processing record 147|nouakchott
# Processing record 148|gat
# City is not found. skipping.
# Processing record 149|jalalpur pirwala
# Processing record 150|bandarbeyla
# Processing record 151|fortuna
# Processing record 152|hopkinton
# City is not found. skipping.
# Processing record 153|guerrero negro
# Processing record 154|honningsvag
# Processing record 155|muros
# Processing record 156|toba
# Processing record 157|road town
# Processing record 158|sainte-anne-des-monts
# City is not found. skipping.
# Processing record 159|kupino
# Processing record 160|columbia
# Processing record 161|vagay
# Processing record 162|saskylakh
# Processing record 163|la plata
# Processing record 164|kutum
# Processing record 165|cabo san lucas
# Processing record 166|bonavista
# Processing record 167|black river
# Processing record 168|baruun-urt
# Processing record 169|torbay
# Processing record 170|ayan
# Processing record 171|jacqueville
# Processing record 172|severo-kurilsk
# Processing record 173|vila franca do campo
# City is not found. skipping.
# Processing record 174|aginskoye
# Processing record 175|ternate
# Processing record 176|dudinka
# Processing record 177|kuna
# Processing record 178|kingston
# Processing record 179|mariinskiy posad
# City is not found. skipping.
# Processing record 180|rapid city
# Processing record 181|udachnyy
# Processing record 182|zhangye
# Processing record 183|saint-francois
# City is not found. skipping.
# Processing record 184|ixtapa
# Processing record 185|payson
# Processing record 186|ilulissat
# Processing record 187|tucumcari
# Processing record 188|gushikawa
# City is not found. skipping.
# Processing record 189|bathsheba
# Processing record 190|sept-iles
# Processing record 191|berezovyy
# City is not found. skipping.
# Processing record 192|verkhoyansk
# Processing record 193|hamilton
# Processing record 194|san patricio
# Processing record 195|songjianghe
# Processing record 196|srednekolymsk
# Processing record 197|novaya bryan
# Processing record 198|nyborg
# Processing record 199|hohhot
# Processing record 200|dingle
# Processing record 201|balesti
# Processing record 202|inta
# Processing record 203|georgetown
# Processing record 204|khorosheve
# Processing record 205|udimskiy
# Processing record 206|brownsville
# Processing record 207|develi
# Processing record 208|nokha
# Processing record 209|puerto ayora
# Processing record 210|chifeng
# Processing record 211|tessalit
# Processing record 212|sorland
# Processing record 213|yar-sale
# Processing record 214|batagay-alyta
# Processing record 215|bayburt
# Processing record 216|sao filipe
# Processing record 217|front royal
# Processing record 218|kashan
# Processing record 219|hauterive
# Processing record 220|grand-lahou
# Processing record 221|thinadhoo
# Processing record 222|chapais
# Processing record 223|hirara
# Processing record 224|banda aceh
# Processing record 225|zaysan
# City is not found. skipping.
# Processing record 226|roald
# Processing record 227|san quintin
# City is not found. skipping.
# Processing record 228|shelopugino
# Processing record 229|lorengau
# Processing record 230|suhbaatar
# Processing record 231|kamaishi
# Processing record 232|praia da vitoria
# Processing record 233|longyearbyen
# Processing record 234|upernavik
# Processing record 235|sosnovo-ozerskoye
# Processing record 236|pangnirtung
# Processing record 237|atar
# Processing record 238|sulangan
# Processing record 239|rongcheng
# Processing record 240|erenhot
# Processing record 241|ostrovnoy
# City is not found. skipping.
# Processing record 242|amapa
# Processing record 243|khandyga
# Processing record 244|alamos
# Processing record 245|norman wells
# Processing record 246|khovu-aksy
# Processing record 247|hay river
# Processing record 248|seoul
# City is not found. skipping.
# Processing record 249|ucluelet
# Processing record 250|havoysund
# City is not found. skipping.
# Processing record 251|borogontsy
# City is not found. skipping.
# Processing record 252|kahului
# Processing record 253|semirara
# Processing record 254|baicheng
# Processing record 255|marienburg
# Processing record 256|agdam
# Processing record 257|gornyy
# Processing record 258|tiznit
# Processing record 259|tanout
# Processing record 260|miri
# Processing record 261|cherskiy
# Processing record 262|saltpond
# City is not found. skipping.
# Processing record 263|mana
# Processing record 264|komsomolskiy
# Processing record 265|hofn
# Processing record 266|hambantota
# Processing record 267|zhigansk
# Processing record 268|sahuaripa
# Processing record 269|novyy urengoy
# Processing record 270|lodwar
# Processing record 271|castro
# Processing record 272|vaini
# Processing record 273|mataura
# Processing record 274|ushuaia
# Processing record 275|port keats
# Processing record 276|hobart
# City is not found. skipping.
# Processing record 277|mahebourg
# Processing record 278|namibe
# Processing record 279|rio brilhante
# Processing record 280|rikitea
# Processing record 281|east london
# Processing record 282|hermanus
# Processing record 283|lufilufi
# Processing record 284|jamestown
# Processing record 285|atuona
# City is not found. skipping.
# Processing record 286|bredasdorp
# Processing record 287|pitimbu
# Processing record 288|christchurch
# Processing record 289|luderitz
# Processing record 290|punta arenas
# Processing record 291|sola
# Processing record 292|lata
# Processing record 293|coihaique
# Processing record 294|nhulunbuy
# Processing record 295|san cristobal
# Processing record 296|barranca
# Processing record 297|namatanai
# Processing record 298|avarua
# Processing record 299|russell
# Processing record 300|vila velha
# Processing record 301|griffith
# Processing record 302|albany
# Processing record 303|comodoro rivadavia
# Processing record 304|puerto ayora
# Processing record 305|avera
# Processing record 306|boyuibe
# Processing record 307|caceres
# Processing record 308|hualmay
# Processing record 309|cidreira
# Processing record 310|busselton
# Processing record 311|asau
# Processing record 312|manga
# Processing record 313|faanui
# Processing record 314|ulladulla
# Processing record 315|mar del plata
# Processing record 316|sambava
# City is not found. skipping.
# Processing record 317|port elizabeth
# City is not found. skipping.
# Processing record 318|cabedelo
# Processing record 319|conceicao do araguaia
# Processing record 320|cape town
# Processing record 321|sao joao da barra
# Processing record 322|hithadhoo
# Processing record 323|piacabucu
# Processing record 324|grand gaube
# Processing record 325|port alfred
# Processing record 326|esperance
# Processing record 327|okahandja
# Processing record 328|huarmey
# Processing record 329|biak
# Processing record 330|morondava
# Processing record 331|mount isa
# Processing record 332|bluff
# Processing record 333|tuatapere
# Processing record 334|rocha
# City is not found. skipping.
# Processing record 335|carnarvon
# City is not found. skipping.
# Processing record 336|auki
# Processing record 337|victoria
# City is not found. skipping.
# Processing record 338|humaita
# Processing record 339|lebu
# Processing record 340|new norfolk
# Processing record 341|talara
# Processing record 342|paragominas
# Processing record 343|mahajanga
# City is not found. skipping.
# Processing record 344|kruisfontein
# Processing record 345|quelimane
# City is not found. skipping.
# Processing record 346|iberia
# Processing record 347|maragogi
# Processing record 348|garissa
# Processing record 349|ceres
# Processing record 350|camacupa
# Processing record 351|mildura
# Processing record 352|alofi
# Processing record 353|omboue
# Processing record 354|arraial do cabo
# Processing record 355|roma
# Processing record 356|bambous virieux
# Processing record 357|ancud
# Processing record 358|flinders
# Processing record 359|diamantino
# Processing record 360|buseresere
# City is not found. skipping.
# Processing record 361|meulaboh
# Processing record 362|saint-philippe
# Processing record 363|muncar
# Processing record 364|itaueira
# Processing record 365|pedra branca
# Processing record 366|georgetown
# City is not found. skipping.
# City is not found. skipping.
# Processing record 367|kindu
# Processing record 368|souillac
# Processing record 369|bengkulu
# Processing record 370|bella union
# Processing record 371|kavieng
# Processing record 372|maceio
# Processing record 373|voh
# Processing record 374|kwinana
# Processing record 375|mairana
# Processing record 376|somerville
# Processing record 377|vallenar
# Processing record 378|karratha
# Processing record 379|kaitangata
# Processing record 380|riberalta
# Processing record 381|menongue
# Processing record 382|gatton
# City is not found. skipping.
# Processing record 383|chuy
# Processing record 384|dunedin
# Processing record 385|te anau
# Processing record 386|manokwari
# Processing record 387|teahupoo
# Processing record 388|kempsey
# Processing record 389|paita
# City is not found. skipping.
# Processing record 390|constitucion
# Processing record 391|malindi
# Processing record 392|sakaraha
# Processing record 393|gamba
# Processing record 394|waipawa
# City is not found. skipping.
# Processing record 395|fortuna
# Processing record 396|ilo
# Processing record 397|mount gambier
# Processing record 398|imbituba
# Processing record 399|casma
# Processing record 400|westport
# Processing record 401|andapa
# City is not found. skipping.
# Processing record 402|ascension
# Processing record 403|samarai
# Processing record 404|daru
# Processing record 405|terra santa
# Processing record 406|belmonte
# Processing record 407|olinda
# Processing record 408|diego de almagro
# Processing record 409|pampas
# Processing record 410|port lincoln
# Processing record 411|karoi
# Processing record 412|padang
# Processing record 413|camana
# Processing record 414|harper
# Processing record 415|beira
# Processing record 416|paso de carrasco
# Processing record 417|kirakira
# City is not found. skipping.
# Processing record 418|laguna
# Processing record 419|graaff-reinet
# Processing record 420|nchelenge
# Processing record 421|sao felix do xingu
# Processing record 422|tucuman
# Processing record 423|richards bay
# Processing record 424|itaituba
# Processing record 425|bima
# Processing record 426|ambon
# Processing record 427|henties bay
# Processing record 428|yulara
# Processing record 429|micheweni
# Processing record 430|teluknaga
# Processing record 431|salta
# Processing record 432|waingapu
# Processing record 433|geraldton
# Processing record 434|kilindoni
# Processing record 435|lavumisa
# Processing record 436|byron bay
# Processing record 437|tautira
# Processing record 438|lubango
# Processing record 439|alice springs
# Processing record 440|charters towers
# Processing record 441|coracao de maria
# Processing record 442|yeppoon
# Processing record 443|san clemente
# Processing record 444|poum
# Processing record 445|requena
# City is not found. skipping.
# Processing record 446|saldanha
# Processing record 447|baturaja
# Processing record 448|rantepao
# Processing record 449|maumere
# Processing record 450|thabazimbi
# City is not found. skipping.
# Processing record 451|lima
# Processing record 452|antalaha
# Processing record 453|ahipara
# Processing record 454|isangel
# Processing record 455|rio gallegos
# Processing record 456|cururupu
# Processing record 457|luanda
# Processing record 458|dubbo
# Processing record 459|tual
# Processing record 460|mbanza-ngungu
# Processing record 461|mwinilunga
# Processing record 462|beroroha
# Processing record 463|port moresby
# Processing record 464|dobson
# Processing record 465|biloela
# Processing record 466|broken hill
# Processing record 467|launceston
# Processing record 468|broome
# Processing record 469|portland
# Processing record 470|touros
# Processing record 471|emerald
# Processing record 472|treinta y tres
# Processing record 473|hanmer springs
# Processing record 474|caaguazu
# Processing record 475|uyuni
# Processing record 476|popondetta
# Processing record 477|perth
# Processing record 478|chipinge
# Processing record 479|soyo
# Processing record 480|nisia floresta
# Processing record 481|kefamenanu
# Processing record 482|rio tercero
# Processing record 483|ibimirim
# Processing record 484|santa rosa
# Processing record 485|coquimbo
# Processing record 486|tefe
# Processing record 487|pasaje
# Processing record 488|jacareacanga
# Processing record 489|saint-joseph
# Processing record 490|koumac
# Processing record 491|bundaberg
# Processing record 492|mackay
# Processing record 493|gizo
# Processing record 494|hokitika
# City is not found. skipping.
# City is not found. skipping.
# Processing record 495|makueni
# Processing record 496|lorengau
# Processing record 497|manta
# Processing record 498|maraa
# Processing record 499|chicama
# Processing record 500|kiama
# Processing record 501|kansanshi
# City is not found. skipping.
# Processing record 502|angoche
# Processing record 503|colac
# Processing record 504|linhares
# Processing record 505|batemans bay
# Processing record 506|caravelas
# Processing record 507|port hedland
# Processing record 508|vaitape
# Processing record 509|ambovombe
# Processing record 510|oshakati
# Processing record 511|corumba
# Processing record 512|dolores
# Processing record 513|maningrida
# Processing record 514|varzea da palma
# Processing record 515|poso
# Processing record 516|san carlos de bariloche
# Processing record 517|kununurra
# Processing record 518|noumea
# Processing record 519|denpasar
# Processing record 520|marica
# Processing record 521|iquique
# Processing record 522|nueva loja
# Processing record 523|rodrigues alves
# Processing record 524|pirapo
# Processing record 525|pangkalanbuun
# Processing record 526|oranjemund
# Processing record 527|necochea
# Processing record 528|laela
# Processing record 529|obidos
# Processing record 530|upington
# Processing record 531|boca do acre
# Processing record 532|prado
# Processing record 533|northam
# Processing record 534|mocuba
# Processing record 535|kupang
# Processing record 536|kalabo
# Processing record 537|finschhafen
# Processing record 538|ambulu
# Processing record 539|opuwo
# Processing record 540|chirongui

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City":cityname, 
                        "Lat":lat,
                        "Lng":lon,
                        "Max Temp":tempmax,
                        "Humidity":humidity,
                        "Cloudiness":clouds, 
                        "Wind Speed":windspeed,
                        "Country":country, 
                        "Date":date})

#Exporting data to csv
weather_df.to_csv(f'../{output_data_file}',index=False)

print(f' There is a total of {len(weather_df.index)} rows of values are contained in this DataFrame')

#Displaying dataframe
weather_df.head()
# Out:
#  There is a total of 540 rows of values are contained in this DataFrame
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Slave Lake  55.2834 -114.7690     36.55        81         100       15.17
# 1   Butaritari   3.0707  172.7902     81.61        79          12       20.18
# 2       Anadyr  64.7500  177.4833     14.50        62           0        6.71
# 3     Buraidah  26.3260   43.9750     71.26        23          54       16.04
# 4  Clyde River  70.4692  -68.5914    -26.90        92          40        3.09
#
#   Country        Date
# 0      CA  1647072443
# 1      KI  1647072443
# 2      RU  1647072443
# 3      SA  1647072443
# 4      CA  1647072444

# %%
Count=[]
Mean=[]
Std=[]
Min=[]
Max=[]
Lowerq =[]
Mediq=[]
Upperq =[]

column_name = weather_df.columns.tolist()
for x in column_name:
    try: 
        Mean.append(weather_df[x].mean())
        Count.append(weather_df[x].count())
        Std.append(weather_df[x].std())
        Min.append(weather_df[x].min())
        Max.append(weather_df[x].max())
        Lowerq.append(weather_df[x].quantile(.25))
        Mediq.append(weather_df[x].quantile(.5))
        Upperq.append(weather_df[x].quantile(.75))


    except TypeError:
        Mean=Mean
        Count=Count
        Std=Std
        Min=Min
        Max=Max
        Lowerq=Lowerq
        Mediq=Mediq
        Upperq=Upperq
        
all_rows = [Count,Mean,Std,Min,Lowerq,Mediq,Upperq,Max]
Summary_df = pd.DataFrame(all_rows, columns=['Lat', 'Lng',"Max Temp","Humidity","Cloudiness","Wind Speed","Date"],
                  index=['count', 'mean',"std","min","25%","50%","75%","max"])
Summary_df
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  540.000000  540.000000  540.000000  540.000000  540.000000  540.000000
# mean    12.585876   16.372500   57.294074   73.046296   61.627778    7.827815
# std     34.347963   93.433327   27.697120   20.996768   41.175361    5.712316
# min    -54.800000 -175.200000  -27.420000   10.000000    0.000000    0.000000
# 25%    -16.817225  -66.409675   40.862500   64.000000   16.000000    3.710000
# 50%      5.847950   17.200000   67.440000   77.000000   82.000000    6.275000
# 75%     42.631100  111.733325   78.580000   88.250000  100.000000   10.540000
# max     78.218600  178.416700  100.450000  100.000000  100.000000   36.100000
#
#                Date
# count  5.400000e+02
# mean   1.647073e+09
# std    6.078721e+01
# min    1.647072e+09
# 25%    1.647072e+09
# 50%    1.647073e+09
# 75%    1.647073e+09
# max    1.647073e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%. <br>
# ___From the above DataFrame,the maximum of humidity is 100%.___<br>
# ___Therefore, no no cities that have humidity > 100%___ <br>
# ___This step is skipped.___

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# The equator has the highest temperature.<br/>
# But overall temperatures in the southern hemisphere are higher than in the northern hemisphere.<br/>
# This is because the surface in the Southern Hemisphere has more water. And water has a high specific heat capacity so it loses heat slowly. <br/>
# I also discovered this while doing the Generate Cities List. For haveing the similar amount of data(300 cities), I only need 600 random points in the southern hemisphere,but 1600 in the northern hemisphere.<br/>

# %%
# %matplotlib notebook
import datetime

today = time.strftime("%m/%d/%Y")
LatitudeTemperature = weather_df.loc[(weather_df["Date"] == 1646986138)]
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Max Temp"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Latitude vs. Max Temperature ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Temperature (Max).png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# There is no obvious correlation between the two variables.<br/>
# But, when the latitude is 0-20, the humidity is the lowest.<br/>
# Afterwards, as the latitude moves to the sides, the humidity gradually increases.<br/>

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Humidity"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Latitude vs. Humidity ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# There is no obvious correlation between the two variables.<br/>
# But cloud cover appears to be centered around 0% and 100%.<br/>
# And in the middle part, the plot has a certain concentration in the 20%, 40% and 75% parts.<br/>

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness (%)")
plt.title(f"Latitude vs. Cloudiness ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# <b/>Conclusion：<br/>
# There is no obvious correlation between the two variables.<br/>
# But for most cities, they have wind speeds between 0-20 mph.<br/>

# %%
# Creat the chart
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"],facecolor = "steelblue", edgecolor = "black")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Latitude vs. Wind Speed ({today})")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Latitude vs. Wind Speed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Linear Regression

# %%
northern_df = weather_df.loc[weather_df["Lat"].astype(float) >=0]
southern_df = weather_df.loc[weather_df["Lat"].astype(float) <=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is -0.87, which means that there is a very strong negative correlation between Max Temp Latitude in the Northern Hemisphere.<br/>
# Temperature decreases with the increase of latitude.<br/>
# Typically:<br/>
# 1.0  = |R|         - Perfect positive/negative correlation<br/>
# 0.8 <= |R| < 1.0   - Very strong positive/negative correlated.<br/>
# 0.6 <= |R| < 0.8   - Strong positive/negative correlated.<br/>
# 0.4 <= |R| < 0.6   - Moderate positive/negative correlated.<br/>
# 0.2 <= |R| < 0.4   - Weak positive/negative correlated.<br/>
# 0.0 <= |R| < 0.2   - Very weak positive/negative correlated.<br/>
# 0.0  = |R|         - No correlated.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(5,5),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Northern Hemisphere - Max Temp vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: -0.8740029381063041

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.52, which means that there is a moderate positive correlation between Max Temp and Latitude in the Southern Hemisphere.<br/>
# Temperature increase with the increase of latitude.<br/>
# This Description matches to the conclusion drawn from the plot `"Latitude vs. Temperature (Max)"` - Besides latitude, the high coverage of surface water is another factor that affects temperatures in Southern Hemisphere.
# Therefore, the correlation between Max Temp and Latitude in the Southern Hemisphere is not as strong as it in Northern Hemisphere.

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,75),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Temperature (F)")
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()


# Save the chart
plt.savefig("../output_WeatherPy/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.5255399639599289

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.36, which means that there is a weak positive correlation between Humidity and Latitude in the Northern Hemisphere.<br/>
# Humidity increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(40,10),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere - Humidity (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.3650408314757755

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.23, which means a weak positive correlation between Humidity and Latitude in the Southern Hemisphere. And it is even weaker in Southern Hemisphere than it is in Northern Hemisphere.<br/>
# Humidity increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,35),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.22743647552343457

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.22, which means that there is a weak positive correlation between Cloudiness and Latitude in the Northern Hemisphere.<br/>
# Cloudiness increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(45,30),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness(%)")
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.22003803543267134

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.44, which means that there is a moderate positive correlation between Cloudiness and Latitude in the Southern Hemisphere. And it is stronger in Southern Hemisphere than it is in Northern Hemisphere.<br/>
# Cloudiness increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,63),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Cloudiness(%)")
plt.title(f"Sorthern Hemisphere - Cloudiness (%) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Sorthern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.43814434358332716

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is 0.01, which means that there is a very weak positive correlation between Wind Speed and Latitude in the Northern Hemisphere.<br/>
# Wind Speed increase with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(0,35),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed(mph)")
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.011072456318598212

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# <b/>Description：<br/>
# The R-value between these two variables is -0.24, which means that there is a weak negative correlation between Wind Speed and Latitude in the Southern Hemisphere. And it is stronger in Southern Hemisphere than it is in Northern Hemisphere. But the linear regression goes to the opposite direction, negative instead of positive.<br/>
# Wind Speed decreade with the increase of latitude.<br/>

# %%
# Print out the r-squared value along with the plot.
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values,y_values,facecolor = "steelblue")
plt.plot(x_values,regress_values,"orangered")
plt.annotate(line_eq,(-55,17.5),fontsize=14,color="orangered")

# Set appearance
plt.xlabel("Latitude(°)")
plt.ylabel("Wind Speed(mph)")
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude ({today})")
print(f"The r-value is: {rvalue}")
plt.show()

# Save the chart
plt.savefig("../output_WeatherPy/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: -0.24128925363448106
